# %%
# %%writefile conf/config.yaml
# # Arch	                        Start Lr	Max Steps	Decay Steps
# # FullyConnectedArch	        1.00E-03	1500000	        15000
# # FourierNetArch                1.00E-03	400000	        7500
# # ModifiedFourierNetArch 	1.00E-03	400000	        7500
# # SirenArch                     2.00E-05	500000	        5000
# # DGMArch                       1.00E-03        1500000         15000
#
# # WARNING: Setting "exact_continuity" to true or setting the arch
# # as "ModifiedFourierNetArch" increases the memory requirements of the
# # problem. Batchsizes may need to be reduced for such cases.
#
# defaults :
#   - modulus_default
#   - arch:
#       - fully_connected
#   - scheduler: exponential_lr
#   - optimizer: adam
#   - loss: sum
#   - _self_
#
# jit: false
#
#
# training:
#   rec_results_freq : 1000
#   rec_constraint_freq: 1000
#   max_steps : 3000
#
# batch_size:
#   initial_condition: 4096
#   interior: 4096
# Out:
# Overwriting conf/config.yaml

# %%
# %%writefile fhn2eqv2.py

from modulus.models.fully_connected import FullyConnectedArch
from modulus.models.fourier_net import FourierNetArch
from modulus.models.siren import SirenArch
from modulus.models.modified_fourier_net import ModifiedFourierNetArch
from modulus.models.dgm import DGMArch

from sympy import Symbol, Eq
from sympy import Symbol, Function, Number
from modulus.eq.pde import PDE
import numpy as np
import matplotlib.pyplot as plt
from scipy import interpolate
import modulus
from modulus.hydra import instantiate_arch, ModulusConfig
from modulus.solver import Solver
from modulus.domain import Domain
from modulus.geometry.primitives_1d import Point1D
from modulus.domain.constraint import (
    PointwiseBoundaryConstraint,
    PointwiseInteriorConstraint,
)
from modulus.domain.validator import PointwiseValidator
from modulus.key import Key
from modulus.node import Node
from modulus.eq.pde import PDE
from modulus.geometry import Parameterization
from sympy import Symbol, Eq, Abs, tanh, Or, And
from modulus.utils.io import (
    csv_to_dict,
    ValidatorPlotter,
    InferencerPlotter,
)
from modulus.solver import SequentialSolver

from modulus.models.deeponet import DeepONetArch
from modulus.domain.constraint.continuous import DeepONetConstraint
from modulus.models.moving_time_window import MovingTimeWindowArch
from modulus.domain.monitor import Monitor
from modulus.domain.constraint import Constraint
from modulus.graph import Graph
from modulus.key import Key
from modulus.constants import TF_SUMMARY
from modulus.distributed import DistributedManager
from modulus.utils.io import dict_to_csv, csv_to_dict
from modulus.domain.inferencer.pointwise import PointwiseInferencer as PointwiseInferencer
from modulus.loss.loss import CausalLossNorm

class MONI(Monitor):
    """
    Pointwise Inferencer that allows inferencing on pointwise data

    Parameters
    ----------
    invar : Dict[str, np.ndarray (N, 1)]
        Dictionary of numpy arrays as input.
    output_names : List[str]
        List of outputs needed for metric.
    metrics : Dict[str, Callable]
        Dictionary of pytorch functions whose input is a dictionary
        torch tensors whose keys are the `output_names`. The keys
        to `metrics` will be used to label the metrics in tensorboard/csv outputs.
    nodes : List[Node]
        List of Modulus Nodes to unroll graph with.
    requires_grad : bool = False
        If automatic differentiation is needed for computing results.
    """

    def __init__(self, invar, output_names, metrics, nodes, requires_grad=False):

        # construct model from nodes
        self.requires_grad = requires_grad
        self.model = Graph(
            nodes, Key.convert_list(invar.keys()), Key.convert_list(output_names)
        )
        self.manager = DistributedManager()
        self.device = self.manager.device
        self.model.to(self.device)

        # set metrics
        self.metrics = metrics
        self.monitor_outvar_store = {}

        # set invar
        self.invar = Constraint._set_device(invar, device=self.device)

    def save_results(self, name, writer, step, data_dir):
        plt.clf()
        # run forward inference
        invar = Constraint._set_device(
            self.invar, device=self.device, requires_grad=self.requires_grad
        )
        outvar = self.model(invar)
        metrics = {key: func({**invar, **outvar}) for key, func in self.metrics.items()}
        t=metrics["t"].detach().cpu().numpy()
        x1=metrics["x1"].detach().cpu().numpy()
        odex1=metrics["ode_x1"].detach().cpu().numpy()
        plt.scatter(t,x1)
        
        plt.savefig(data_dir+"x1s"+str(step)+".png")
        plt.clf()
        plt.scatter(t,odex1)
       # print(t)

        
        plt.savefig(data_dir+"ode_x1s"+str(step)+".png")
       
        return metrics

    
t_max = 10.0
n_w=10
t_w= t_max/n_w
def generateExactSolution(t,dt,x0,w0,rate,P,begin,end):
    
    
    n2=int(t/(dt))+2
    n = int((end-begin)/(dt*rate))
    Sol=np.zeros((n,3))
  
    Sol2=np.zeros((n2,2))
    Sol2[0]=0.6,0
    T=0
    k=0
    while(k<n2-1):
        x,w=Sol2[k]
        Sol2[k+1]=10*(x*(x-0.4)*(1-x)-w)*dt+  x, 0.5*(x*0.2-0.8*w)*dt +w
 
        if ((k*dt==begin or ((k+1)%rate == 0 and k*dt>=begin and k*dt<=end))and T<n):
          
           
            Sol[T] = Sol2[k][0],Sol2[k][1] , k*dt
            T=T+1
        
        k=k+1
        if(k*dt > end):
            break
    return Sol

def generateValidator(w_i,nodes):

    
    
    T=np.empty([0])
    K=np.empty([0])
    SOLs=np.empty([0])
    SOLw=np.empty([0])
    V=np.empty([0])
    krange= [(0 + 0.05*i*1) for i in range(0,20)]
    vrange= [(0 + 0.05*i*1) for i in range(0,20)]

    deltaT = 0.01
    
    rate=20
    for KR in krange:
        for VR in vrange:
            begin=w_i* t_w
            end=begin + t_w
            sol=generateExactSolution(t_max,deltaT,KR,VR,rate,KR,begin,end)

            T=sol.T[2] - begin
            SOLs=sol.T[0]
            SOLw=sol.T[1]
    
    
    t = np.expand_dims(T, axis=-1)


    k = np.expand_dims(K, axis=-1)

    
    Solx = np.expand_dims(SOLs, axis=-1)

    
    Solw = np.expand_dims(SOLw, axis=-1)
   
    v= np.expand_dims(V,axis=-1)
    print(t,"val set de ",begin,"a ", end)

    
    invar_numpy = {"t": t}
    outvar_numpy = {
        "x1": Solx,
        "w":Solw
    }
   
    validator = PointwiseValidator(
        nodes=nodes, invar=invar_numpy, true_outvar=outvar_numpy, batch_size=100,plotter=None
    )
    return validator




class SpringMass(PDE):
    name = "SpringMass"

    def __init__(self):

        t = Symbol("t")
       
        input_variables = {"t": t}

        x = Function("x1")(*input_variables)
        w= Function("w")(*input_variables)
        self.equations = {}
        self.equations["ode_x1"] =10*(x*(x-0.4)*(1-x)-w) -x.diff(t)
        self.equations["ode_w"]  =0.5*(x*0.2-0.8*w) -w.diff(t)
        
@modulus.main(config_path="conf", config_name="config")
def run(cfg: ModulusConfig) -> None:
    
    # make list of nodes to unroll graph on
    sm = SpringMass()
    sm.pprint()
    #sm_net = FullyConnectedArch(
    #    input_keys=[Key("t"), Key("K")],
    #    output_keys=[Key("x1")],
    #)
    #nodes = sm.make_nodes() + [
    #    sm_net.make_node(name="network")
    #]


    
    # make list of nodes to unroll graph on
    sm = SpringMass()
    sm.pprint()
    #sm_net = FullyConnectedArch(
    #    input_keys=[Key("t"), Key("K")],
    #    output_keys=[Key("x1")],
    #)
    #nodes = sm.make_nodes() + [
    #    sm_net.make_node(name="network")
    #]

    
    
    flow_net = FullyConnectedArch(
            input_keys=[Key("t")],
            output_keys=[Key("x1"),Key("w")],
            layer_size=300,
            nr_layers=10,
        )

    

    time_window_net = MovingTimeWindowArch(flow_net, t_w)

    nodes = sm.make_nodes() +[time_window_net.make_node(name="network")]


    for node in nodes:
        print(node.__str__())
   
    # add constraints to solver
    # make geometry
    geo = Point1D(0)
    
    t_symbol = Symbol("t")
    x_symbol = Symbol("x1")


    time_range = {t_symbol: (0,t_w )}
  

    tr = {t_symbol: (0, t_w)}

    # make domain
        # make initial condition domain
    ic_domain = Domain("initial_conditions")

  
    IC = PointwiseBoundaryConstraint(
        nodes=nodes,
        geometry=geo,
        outvar={"x1": 0.6,"w":0},
        batch_size=2000,
        parameterization={**{t_symbol:0}},
        lambda_weighting={
            "x1": 100.0,#* ((t_symbol/t_max)) + 10,
            "w": 100.0,
        },  
        
        quasirandom=True,
    )
    ic_domain.add_constraint(IC, name="IC")
    
    interior = PointwiseBoundaryConstraint(
        nodes=nodes,
        geometry=geo,
        outvar={"ode_x1": 0.0,"ode_w":0.0},
        batch_size=500,
        parameterization={**time_range},
        #criteria=And(t_symbol > 0, t_symbol < 3),
        lambda_weighting={
            "ode_x1":10,#* ((t_symbol/t_max)) + 10,
            "ode_w": 10  #* ((t_symbol/t_max)) + 1
        },
        quasirandom=True,
        loss=CausalLossNorm(eps=1.0),

    )
    ic_domain.add_constraint(interior, name="interior")
    
    
       
    
    domains=[]
    for i in range(1,n_w):

        # make moving window domain
        window_domain = Domain("window"+str(i))

        # solve over given time period
        interior1 = PointwiseBoundaryConstraint(
        nodes=nodes,
        geometry=geo,
        outvar={"ode_x1": 0.0,"ode_w":0.0},
        batch_size=2000,
        parameterization={**tr},
        #criteria=And(t_symbol > 0, t_symbol < 3),
        lambda_weighting={
            "ode_x1": 1,# + 1000*x_symbol.diff(t_symbol)*x_symbol.diff(t_symbol),
            "ode_w": 1 #+ 1000*x_symbol.diff(t_symbol)*x_symbol.diff(t_symbol)
        },
        quasirandom=True,
        loss=CausalLossNorm(eps=1.0),
        )


        
        
        IC = PointwiseBoundaryConstraint(
        nodes=nodes,
        geometry=geo,
        outvar={"x1_prev_step_diff":0,"w_prev_step_diff":0},
        batch_size=500,
        parameterization={**{t_symbol:0}},
        lambda_weighting={
            "x1_prev_step_diff": 100,
            "w_prev_step_diff": 100
        },
        
        quasirandom=True,
        
    )
        
    
        
        window_domain.add_constraint(IC, name="IC")
        window_domain.add_constraint(interior1, "interior")


        domains.append(window_domain)
    

    
 
    
    

    
    dom=[]
    dom.append((1,ic_domain))

    for domain in domains:
        dom.append((1,domain))
    print(cfg)
    # make solver
    #slv = Solver(cfg, domain)
    #print(domains)
    i=0
    for a,d in dom:
        print(d)
        print(d.name)
        d.add_validator(generateValidator(i,nodes))

        
        i=i+1
    
      
    slv = SequentialSolver(
        cfg,
        dom,
        custom_update_operation=time_window_net.move_window,


    )

    # start solver
    slv.solve()

        
        
        
if __name__ == "__main__":
    run()
# Out:
# Overwriting fhn2eqv2.py

# %%
# !rm -r outputs/fhn2eqv2 || true ##se não limpar o output ele aproveita o treinamento, mesmo se mudar o modelo
# !python fhn2eqv2.py
# Out:
# [20:09:50] - JitManager: {'_enabled': False, '_arch_mode': <JitArchMode.ONLY_ACTIVATION: 1>, '_use_nvfuser': True, '_autograd_nodes': False}
# [20:09:50] - GraphManager: {'_func_arch': False, '_debug': False, '_func_arch_allow_partial_hessian': True}
# ode_x1: 10*(1 - x1)*(x1 - 0.4)*x1 - 10*w - x1__t
# ode_w: -0.4*w + 0.1*x1 - w__t
# ode_x1: 10*(1 - x1)*(x1 - 0.4)*x1 - 10*w - x1__t
# ode_w: -0.4*w + 0.1*x1 - w__t
# node: Sympy Node: ode_x1
# evaluate: SympyToTorch
# inputs: [w, x1]
# derivatives: [x1__t]
# outputs: [ode_x1]
# optimize: False
# node: Sympy Node: ode_w
# evaluate: SympyToTorch
# inputs: [w, x1]
# derivatives: [w__t]
# outputs: [ode_w]
# optimize: False
# node: Arch Node: network
# evaluate: MovingTimeWindowArch
# inputs: [t]
# derivatives: []
# outputs: [x1, w, x1_prev_step, w_prev_step, x1_prev_step_diff, w_prev_step_diff]
# optimize: True
# {'training': {'max_steps': 3000, 'grad_agg_freq': 1, 'rec_results_freq': 1000, 'rec_validation_freq': '${training.rec_results_freq}', 'rec_inference_freq': '${training.rec_results_freq}', 'rec_monitor_freq': '${training.rec_results_freq}', 'rec_constraint_freq': 1000, 'save_network_freq': 1000, 'print_stats_freq': 100, 'summary_freq': 1000, 'amp': False, 'amp_dtype': 'float16', 'ntk': {'use_ntk': False, 'save_name': None, 'run_freq': 1000}}, 'graph': {'func_arch': False, 'func_arch_allow_partial_hessian': True}, 'stop_criterion': {'metric': None, 'min_delta': None, 'patience': 50000, 'mode': 'min', 'freq': 1000, 'strict': False}, 'profiler': {'profile': False, 'start_step': 0, 'end_step': 100, 'name': 'nvtx'}, 'network_dir': '.', 'initialization_network_dir': '', 'save_filetypes': 'vtk', 'summary_histograms': False, 'jit': False, 'jit_use_nvfuser': True, 'jit_arch_mode': 'only_activation', 'jit_autograd_nodes': False, 'cuda_graphs': True, 'cuda_graph_warmup': 20, 'find_unused_parameters': False, 'broadcast_buffers': False, 'device': '', 'debug': False, 'run_mode': 'train', 'arch': {'fully_connected': {'arch_type': 'fully_connected', 'input_keys': '???', 'output_keys': '???', 'detach_keys': '???', 'scaling': None, 'layer_size': 512, 'nr_layers': 6, 'skip_connections': False, 'activation_fn': 'silu', 'adaptive_activations': False, 'weight_norm': True}}, 'models': '???', 'loss': {'_target_': 'modulus.loss.aggregator.Sum', 'weights': None}, 'optimizer': {'_params_': {'compute_gradients': 'adam_compute_gradients', 'apply_gradients': 'adam_apply_gradients'}, '_target_': 'torch.optim.Adam', 'lr': 0.001, 'betas': [0.9, 0.999], 'eps': 1e-08, 'weight_decay': 0.0, 'amsgrad': False}, 'scheduler': {'_target_': 'torch.optim.lr_scheduler.ExponentialLR', 'gamma': 0.99998718}, 'batch_size': {'initial_condition': 4096, 'interior': 4096}, 'custom': '???'}
# <modulus.domain.domain.Domain object at 0x7f75968693d0>
# initial_conditions
# [[0.  ]
#  [0.19]
#  [0.39]
#  [0.59]
#  [0.79]] val set de  0.0 a  1.0
# <modulus.domain.domain.Domain object at 0x7f75968696a0>
# window1
# [[0.  ]
#  [0.19]
#  [0.39]
#  [0.59]
#  [0.79]] val set de  1.0 a  2.0
# <modulus.domain.domain.Domain object at 0x7f7596869280>
# window2
# [[0.  ]
#  [0.19]
#  [0.39]
#  [0.59]
#  [0.79]] val set de  2.0 a  3.0
# <modulus.domain.domain.Domain object at 0x7f7596871100>
# window3
# [[0.  ]
#  [0.19]
#  [0.39]
#  [0.59]
#  [0.79]] val set de  3.0 a  4.0
# <modulus.domain.domain.Domain object at 0x7f7595f90ca0>
# window4
# [[0.  ]
#  [0.19]
#  [0.39]
#  [0.59]
#  [0.79]] val set de  4.0 a  5.0
# <modulus.domain.domain.Domain object at 0x7f7595f9aca0>
# window5
# [[0.  ]
#  [0.19]
#  [0.39]
#  [0.59]
#  [0.79]] val set de  5.0 a  6.0
# <modulus.domain.domain.Domain object at 0x7f7595fa2ca0>
# window6
# [[0.  ]
#  [0.19]
#  [0.39]
#  [0.59]
#  [0.79]] val set de  6.0 a  7.0
# <modulus.domain.domain.Domain object at 0x7f7595fb0ca0>
# window7
# [[0.  ]
#  [0.19]
#  [0.39]
#  [0.59]
#  [0.79]] val set de  7.0 a  8.0
# <modulus.domain.domain.Domain object at 0x7f7595fbaca0>
# window8
# [[0.  ]
#  [0.19]
#  [0.39]
#  [0.59]
#  [0.79]] val set de  8.0 a  9.0
# <modulus.domain.domain.Domain object at 0x7f7595fc5ca0>
# window9
# [[0.  ]
#  [0.19]
#  [0.39]
#  [0.59]
#  [0.79]] val set de  9.0 a  10.0
# [20:10:01] - Solving for Domain initial_conditions, iteration 0
# [20:10:01] - attempting to restore from: outputs/fhn2eqv2/initial_conditions
# [20:10:01] - optimizer checkpoint not found
# [20:10:01] - model network.0.pth not found
# [20:10:02] - [step:          0] record constraint batch time:  3.365e-02s
# [20:10:02] - [step:          0] record validators time:  4.310e-03s
# [20:10:02] - [step:          0] saved checkpoint to outputs/fhn2eqv2/initial_conditions
# [20:10:02] - [step:          0] loss:  3.601e+01
# [20:10:03] - Attempting cuda graph building, this may take a bit...
# [20:10:04] - [step:        100] loss:  1.019e-02, time/iteration:  2.028e+01 ms
# [20:10:06] - [step:        200] loss:  2.185e-02, time/iteration:  1.619e+01 ms
# [20:10:08] - [step:        300] loss:  7.838e-03, time/iteration:  1.618e+01 ms
# [20:10:09] - [step:        400] loss:  4.194e-03, time/iteration:  1.618e+01 ms
# [20:10:11] - [step:        500] loss:  1.677e-02, time/iteration:  1.616e+01 ms
# [20:10:12] - [step:        600] loss:  6.438e-03, time/iteration:  1.612e+01 ms
# [20:10:14] - [step:        700] loss:  5.169e-03, time/iteration:  1.614e+01 ms
# [20:10:16] - [step:        800] loss:  3.184e-03, time/iteration:  1.614e+01 ms
# [20:10:17] - [step:        900] loss:  8.939e-04, time/iteration:  1.612e+01 ms
# [20:10:19] - [step:       1000] record constraint batch time:  3.287e-02s
# [20:10:19] - [step:       1000] record validators time:  4.049e-03s
# [20:10:19] - [step:       1000] saved checkpoint to outputs/fhn2eqv2/initial_conditions
# [20:10:19] - [step:       1000] loss:  1.806e-02, time/iteration:  2.033e+01 ms
# [20:10:21] - [step:       1100] loss:  2.842e-03, time/iteration:  1.634e+01 ms
# [20:10:22] - [step:       1200] loss:  1.652e-02, time/iteration:  1.617e+01 ms
# [20:10:24] - [step:       1300] loss:  2.685e-02, time/iteration:  1.620e+01 ms
# [20:10:26] - [step:       1400] loss:  4.387e-03, time/iteration:  1.620e+01 ms
# [20:10:27] - [step:       1500] loss:  2.990e-03, time/iteration:  1.619e+01 ms
# [20:10:29] - [step:       1600] loss:  1.300e-02, time/iteration:  1.629e+01 ms
# [20:10:31] - [step:       1700] loss:  6.648e-03, time/iteration:  1.633e+01 ms
# [20:10:32] - [step:       1800] loss:  4.246e-03, time/iteration:  1.621e+01 ms
# [20:10:34] - [step:       1900] loss:  2.361e-03, time/iteration:  1.639e+01 ms
# [20:10:36] - [step:       2000] record constraint batch time:  3.892e-02s
# [20:10:36] - [step:       2000] record validators time:  4.131e-03s
# [20:10:36] - [step:       2000] saved checkpoint to outputs/fhn2eqv2/initial_conditions
# [20:10:36] - [step:       2000] loss:  3.823e-03, time/iteration:  2.047e+01 ms
# [20:10:38] - [step:       2100] loss:  1.228e-03, time/iteration:  1.638e+01 ms
# [20:10:39] - [step:       2200] loss:  8.098e-04, time/iteration:  1.622e+01 ms
# [20:10:41] - [step:       2300] loss:  5.012e-03, time/iteration:  1.625e+01 ms
# [20:10:42] - [step:       2400] loss:  2.433e-03, time/iteration:  1.625e+01 ms
# [20:10:44] - [step:       2500] loss:  4.836e-03, time/iteration:  1.626e+01 ms
# [20:10:46] - [step:       2600] loss:  5.911e-03, time/iteration:  1.624e+01 ms
# [20:10:47] - [step:       2700] loss:  4.072e-03, time/iteration:  1.626e+01 ms
# [20:10:49] - [step:       2800] loss:  5.074e-04, time/iteration:  1.627e+01 ms
# [20:10:51] - [step:       2900] loss:  1.458e-03, time/iteration:  1.628e+01 ms
# [20:10:53] - [step:       3000] record constraint batch time:  2.080e-02s
# [20:10:53] - [step:       3000] record validators time:  4.014e-03s
# [20:10:53] - [step:       3000] saved checkpoint to outputs/fhn2eqv2/initial_conditions
# [20:10:53] - [step:       3000] loss:  1.786e-03, time/iteration:  2.034e+01 ms
# [20:10:53] - [step:       3000] reached maximum training steps, finished training!
# [20:10:53] - Solving for Domain window1, iteration 0
# [20:10:53] - attempting to restore from: outputs/fhn2eqv2/window1
# [20:10:53] - optimizer checkpoint not found
# [20:10:53] - model network.0.pth not found
# [20:10:53] - [step:          0] record constraint batch time:  2.550e-02s
# [20:10:53] - [step:          0] record validators time:  4.030e-03s
# [20:10:53] - [step:          0] saved checkpoint to outputs/fhn2eqv2/window1
# [20:10:53] - [step:          0] loss:  2.396e-02
# [20:10:53] - Attempting cuda graph building, this may take a bit...
# [20:10:56] - [step:        100] loss:  2.024e-03, time/iteration:  2.949e+01 ms
# [20:10:59] - [step:        200] loss:  1.302e-03, time/iteration:  2.688e+01 ms
# [20:11:01] - [step:        300] loss:  6.274e-04, time/iteration:  2.694e+01 ms
# [20:11:04] - [step:        400] loss:  1.481e-04, time/iteration:  2.695e+01 ms
# [20:11:07] - [step:        500] loss:  6.253e-05, time/iteration:  2.697e+01 ms
# [20:11:09] - [step:        600] loss:  4.702e-05, time/iteration:  2.693e+01 ms
# [20:11:12] - [step:        700] loss:  7.868e-05, time/iteration:  2.697e+01 ms
# [20:11:15] - [step:        800] loss:  3.181e-05, time/iteration:  2.702e+01 ms
# [20:11:17] - [step:        900] loss:  3.445e-05, time/iteration:  2.698e+01 ms
# [20:11:20] - [step:       1000] record constraint batch time:  3.104e-02s
# [20:11:20] - [step:       1000] record validators time:  4.045e-03s
# [20:11:20] - [step:       1000] saved checkpoint to outputs/fhn2eqv2/window1
# [20:11:20] - [step:       1000] loss:  3.520e-05, time/iteration:  3.120e+01 ms
# [20:11:23] - [step:       1100] loss:  7.369e-05, time/iteration:  2.720e+01 ms
# [20:11:26] - [step:       1200] loss:  4.465e-05, time/iteration:  2.704e+01 ms
# [20:11:29] - [step:       1300] loss:  1.352e-03, time/iteration:  2.706e+01 ms
# [20:11:31] - [step:       1400] loss:  1.374e-03, time/iteration:  2.707e+01 ms
# [20:11:34] - [step:       1500] loss:  2.873e-03, time/iteration:  2.709e+01 ms
# [20:11:37] - [step:       1600] loss:  5.708e-05, time/iteration:  2.724e+01 ms
# [20:11:39] - [step:       1700] loss:  8.994e-04, time/iteration:  2.724e+01 ms
# [20:11:42] - [step:       1800] loss:  1.528e-04, time/iteration:  2.728e+01 ms
# [20:11:45] - [step:       1900] loss:  1.553e-04, time/iteration:  2.722e+01 ms
# [20:11:48] - [step:       2000] record constraint batch time:  4.330e-02s
# [20:11:48] - [step:       2000] record validators time:  4.155e-03s
# [20:11:48] - [step:       2000] saved checkpoint to outputs/fhn2eqv2/window1
# [20:11:48] - [step:       2000] loss:  2.211e-04, time/iteration:  3.127e+01 ms
# [20:11:51] - [step:       2100] loss:  5.498e-03, time/iteration:  2.729e+01 ms
# [20:11:54] - [step:       2200] loss:  1.072e-04, time/iteration:  2.713e+01 ms
# [20:11:56] - [step:       2300] loss:  1.297e-04, time/iteration:  2.715e+01 ms
# [20:11:59] - [step:       2400] loss:  1.536e-03, time/iteration:  2.715e+01 ms
# [20:12:02] - [step:       2500] loss:  2.673e-05, time/iteration:  2.715e+01 ms
# [20:12:04] - [step:       2600] loss:  2.075e-03, time/iteration:  2.719e+01 ms
# [20:12:07] - [step:       2700] loss:  6.178e-04, time/iteration:  2.718e+01 ms
# [20:12:10] - [step:       2800] loss:  7.447e-04, time/iteration:  2.719e+01 ms
# [20:12:13] - [step:       2900] loss:  2.791e-04, time/iteration:  2.721e+01 ms
# [20:12:16] - [step:       3000] record constraint batch time:  2.475e-02s
# [20:12:16] - [step:       3000] record validators time:  4.220e-03s
# [20:12:16] - [step:       3000] saved checkpoint to outputs/fhn2eqv2/window1
# [20:12:16] - [step:       3000] loss:  1.286e-04, time/iteration:  3.142e+01 ms
# [20:12:16] - [step:       3000] reached maximum training steps, finished training!
# [20:12:16] - Solving for Domain window2, iteration 0
# [20:12:16] - attempting to restore from: outputs/fhn2eqv2/window2
# [20:12:16] - optimizer checkpoint not found
# [20:12:16] - model network.0.pth not found
# [20:12:16] - [step:          0] record constraint batch time:  2.379e-02s
# [20:12:16] - [step:          0] record validators time:  4.072e-03s
# [20:12:16] - [step:          0] saved checkpoint to outputs/fhn2eqv2/window2
# [20:12:16] - [step:          0] loss:  2.295e+01
# [20:12:17] - Attempting cuda graph building, this may take a bit...
# [20:12:19] - [step:        100] loss:  3.561e-02, time/iteration:  2.992e+01 ms
# [20:12:22] - [step:        200] loss:  1.936e-02, time/iteration:  2.744e+01 ms
# [20:12:24] - [step:        300] loss:  1.521e-02, time/iteration:  2.725e+01 ms
# [20:12:27] - [step:        400] loss:  1.295e-02, time/iteration:  2.731e+01 ms
# [20:12:30] - [step:        500] loss:  1.352e-02, time/iteration:  2.725e+01 ms
# [20:12:33] - [step:        600] loss:  1.292e-02, time/iteration:  2.727e+01 ms
# [20:12:35] - [step:        700] loss:  1.197e-02, time/iteration:  2.726e+01 ms
# [20:12:38] - [step:        800] loss:  2.113e-02, time/iteration:  2.727e+01 ms
# [20:12:41] - [step:        900] loss:  1.060e-02, time/iteration:  2.727e+01 ms
# [20:12:44] - [step:       1000] record constraint batch time:  3.205e-02s
# [20:12:44] - [step:       1000] record validators time:  4.414e-03s
# [20:12:44] - [step:       1000] saved checkpoint to outputs/fhn2eqv2/window2
# [20:12:44] - [step:       1000] loss:  2.195e-02, time/iteration:  3.172e+01 ms
# [20:12:47] - [step:       1100] loss:  7.318e-03, time/iteration:  2.756e+01 ms
# [20:12:49] - [step:       1200] loss:  6.299e-03, time/iteration:  2.736e+01 ms
# [20:12:52] - [step:       1300] loss:  6.142e-03, time/iteration:  2.738e+01 ms
# [20:12:55] - [step:       1400] loss:  4.705e-03, time/iteration:  2.733e+01 ms
# [20:12:58] - [step:       1500] loss:  3.193e-03, time/iteration:  2.733e+01 ms
# [20:13:00] - [step:       1600] loss:  8.313e-03, time/iteration:  2.746e+01 ms
# [20:13:03] - [step:       1700] loss:  1.045e-03, time/iteration:  2.736e+01 ms
# [20:13:06] - [step:       1800] loss:  7.378e-04, time/iteration:  2.735e+01 ms
# [20:13:09] - [step:       1900] loss:  1.438e-04, time/iteration:  2.759e+01 ms
# [20:13:12] - [step:       2000] record constraint batch time:  4.405e-02s
# [20:13:12] - [step:       2000] record validators time:  4.184e-03s
# [20:13:12] - [step:       2000] saved checkpoint to outputs/fhn2eqv2/window2
# [20:13:12] - [step:       2000] loss:  3.201e-04, time/iteration:  3.165e+01 ms
# [20:13:15] - [step:       2100] loss:  1.872e-04, time/iteration:  2.764e+01 ms
# [20:13:17] - [step:       2200] loss:  4.417e-03, time/iteration:  2.737e+01 ms
# [20:13:20] - [step:       2300] loss:  1.368e-03, time/iteration:  2.736e+01 ms
# [20:13:23] - [step:       2400] loss:  1.849e-04, time/iteration:  2.738e+01 ms
# [20:13:26] - [step:       2500] loss:  1.181e-04, time/iteration:  2.740e+01 ms
# [20:13:28] - [step:       2600] loss:  5.539e-04, time/iteration:  2.736e+01 ms
# [20:13:31] - [step:       2700] loss:  8.138e-04, time/iteration:  2.740e+01 ms
# [20:13:34] - [step:       2800] loss:  3.453e-04, time/iteration:  2.743e+01 ms
# [20:13:36] - [step:       2900] loss:  1.131e-03, time/iteration:  2.744e+01 ms
# [20:13:40] - [step:       3000] record constraint batch time:  2.465e-02s
# [20:13:40] - [step:       3000] record validators time:  4.078e-03s
# [20:13:40] - [step:       3000] saved checkpoint to outputs/fhn2eqv2/window2
# [20:13:40] - [step:       3000] loss:  6.348e-05, time/iteration:  3.163e+01 ms
# [20:13:40] - [step:       3000] reached maximum training steps, finished training!
# [20:13:40] - Solving for Domain window3, iteration 0
# [20:13:40] - attempting to restore from: outputs/fhn2eqv2/window3
# [20:13:40] - optimizer checkpoint not found
# [20:13:40] - model network.0.pth not found
# [20:13:40] - [step:          0] record constraint batch time:  2.441e-02s
# [20:13:40] - [step:          0] record validators time:  4.295e-03s
# [20:13:40] - [step:          0] saved checkpoint to outputs/fhn2eqv2/window3
# [20:13:40] - [step:          0] loss:  9.988e-02
# [20:13:40] - Attempting cuda graph building, this may take a bit...
# [20:13:43] - [step:        100] loss:  2.697e-03, time/iteration:  3.031e+01 ms
# [20:13:46] - [step:        200] loss:  7.461e-04, time/iteration:  2.741e+01 ms
# [20:13:48] - [step:        300] loss:  1.019e-04, time/iteration:  2.746e+01 ms
# [20:13:51] - [step:        400] loss:  4.254e-05, time/iteration:  2.742e+01 ms
# [20:13:54] - [step:        500] loss:  4.312e-05, time/iteration:  2.744e+01 ms
# [20:13:57] - [step:        600] loss:  3.960e-05, time/iteration:  2.752e+01 ms
# [20:13:59] - [step:        700] loss:  3.787e-05, time/iteration:  2.757e+01 ms
# [20:14:02] - [step:        800] loss:  3.408e-05, time/iteration:  2.749e+01 ms
# [20:14:05] - [step:        900] loss:  3.374e-05, time/iteration:  2.760e+01 ms
# [20:14:08] - [step:       1000] record constraint batch time:  3.115e-02s
# [20:14:08] - [step:       1000] record validators time:  4.196e-03s
# [20:14:08] - [step:       1000] saved checkpoint to outputs/fhn2eqv2/window3
# [20:14:08] - [step:       1000] loss:  5.048e-05, time/iteration:  3.170e+01 ms
# [20:14:11] - [step:       1100] loss:  3.225e-05, time/iteration:  2.760e+01 ms
# [20:14:14] - [step:       1200] loss:  2.806e-05, time/iteration:  2.746e+01 ms
# [20:14:16] - [step:       1300] loss:  9.120e-04, time/iteration:  2.748e+01 ms
# [20:14:19] - [step:       1400] loss:  3.103e-05, time/iteration:  2.743e+01 ms
# [20:14:22] - [step:       1500] loss:  2.195e-05, time/iteration:  2.749e+01 ms
# [20:14:25] - [step:       1600] loss:  1.910e-05, time/iteration:  2.752e+01 ms
# [20:14:27] - [step:       1700] loss:  2.519e-05, time/iteration:  2.754e+01 ms
# [20:14:30] - [step:       1800] loss:  2.643e-05, time/iteration:  2.750e+01 ms
# [20:14:33] - [step:       1900] loss:  1.613e-05, time/iteration:  2.754e+01 ms
# [20:14:36] - [step:       2000] record constraint batch time:  4.326e-02s
# [20:14:36] - [step:       2000] record validators time:  4.101e-03s
# [20:14:36] - [step:       2000] saved checkpoint to outputs/fhn2eqv2/window3
# [20:14:36] - [step:       2000] loss:  1.320e-05, time/iteration:  3.170e+01 ms
# [20:14:39] - [step:       2100] loss:  1.240e-05, time/iteration:  2.763e+01 ms
# [20:14:42] - [step:       2200] loss:  5.152e-03, time/iteration:  2.755e+01 ms
# [20:14:44] - [step:       2300] loss:  1.274e-05, time/iteration:  2.751e+01 ms
# [20:14:47] - [step:       2400] loss:  9.939e-06, time/iteration:  2.756e+01 ms
# [20:14:50] - [step:       2500] loss:  8.610e-06, time/iteration:  2.753e+01 ms
# [20:14:53] - [step:       2600] loss:  3.505e-03, time/iteration:  2.752e+01 ms
# [20:14:55] - [step:       2700] loss:  8.251e-06, time/iteration:  2.751e+01 ms
# [20:14:58] - [step:       2800] loss:  7.201e-06, time/iteration:  2.756e+01 ms
# [20:15:01] - [step:       2900] loss:  1.132e-02, time/iteration:  2.751e+01 ms
# [20:15:04] - [step:       3000] record constraint batch time:  2.462e-02s
# [20:15:04] - [step:       3000] record validators time:  4.088e-03s
# [20:15:04] - [step:       3000] saved checkpoint to outputs/fhn2eqv2/window3
# [20:15:04] - [step:       3000] loss:  7.346e-06, time/iteration:  3.163e+01 ms
# [20:15:04] - [step:       3000] reached maximum training steps, finished training!
# [20:15:04] - Solving for Domain window4, iteration 0
# [20:15:04] - attempting to restore from: outputs/fhn2eqv2/window4
# [20:15:04] - optimizer checkpoint not found
# [20:15:04] - model network.0.pth not found
# [20:15:04] - [step:          0] record constraint batch time:  2.354e-02s
# [20:15:04] - [step:          0] record validators time:  4.037e-03s
# [20:15:04] - [step:          0] saved checkpoint to outputs/fhn2eqv2/window4
# [20:15:04] - [step:          0] loss:  5.385e-05
# [20:15:05] - Attempting cuda graph building, this may take a bit...
# [20:15:07] - [step:        100] loss:  8.108e-04, time/iteration:  3.052e+01 ms
# [20:15:10] - [step:        200] loss:  2.352e-04, time/iteration:  2.727e+01 ms
# [20:15:13] - [step:        300] loss:  3.031e-05, time/iteration:  2.741e+01 ms
# [20:15:15] - [step:        400] loss:  2.507e-05, time/iteration:  2.719e+01 ms
# [20:15:18] - [step:        500] loss:  2.323e-05, time/iteration:  2.718e+01 ms
# [20:15:21] - [step:        600] loss:  2.121e-05, time/iteration:  2.705e+01 ms
# [20:15:24] - [step:        700] loss:  3.700e-05, time/iteration:  2.701e+01 ms
# [20:15:26] - [step:        800] loss:  1.109e-03, time/iteration:  2.697e+01 ms
# [20:15:29] - [step:        900] loss:  2.039e-05, time/iteration:  2.698e+01 ms
# [20:15:32] - [step:       1000] record constraint batch time:  3.148e-02s
# [20:15:32] - [step:       1000] record validators time:  4.287e-03s
# [20:15:32] - [step:       1000] saved checkpoint to outputs/fhn2eqv2/window4
# [20:15:32] - [step:       1000] loss:  7.769e-05, time/iteration:  3.111e+01 ms
# [20:15:35] - [step:       1100] loss:  1.893e-05, time/iteration:  2.707e+01 ms
# [20:15:38] - [step:       1200] loss:  1.014e-04, time/iteration:  2.689e+01 ms
# [20:15:40] - [step:       1300] loss:  1.635e-05, time/iteration:  2.687e+01 ms
# [20:15:43] - [step:       1400] loss:  2.639e-05, time/iteration:  2.686e+01 ms
# [20:15:46] - [step:       1500] loss:  2.756e-05, time/iteration:  2.689e+01 ms
# [20:15:48] - [step:       1600] loss:  2.579e-05, time/iteration:  2.685e+01 ms
# [20:15:51] - [step:       1700] loss:  7.839e-05, time/iteration:  2.681e+01 ms
# [20:15:54] - [step:       1800] loss:  1.885e-04, time/iteration:  2.694e+01 ms
# [20:15:56] - [step:       1900] loss:  5.144e-05, time/iteration:  2.702e+01 ms
# [20:16:43] - [step:        600] loss:  6.227e-03, time/iteration:  2.687e+01 ms
# [20:16:46] - [step:        700] loss:  2.066e-05, time/iteration:  2.682e+01 ms
# [20:16:49] - [step:        800] loss:  8.661e-05, time/iteration:  2.676e+01 ms
# [20:16:51] - [step:        900] loss:  2.672e-04, time/iteration:  2.669e+01 ms
# [20:16:54] - [step:       1000] record constraint batch time:  3.111e-02s
# [20:16:54] - [step:       1000] record validators time:  4.210e-03s
# [20:16:54] - [step:       1000] saved checkpoint to outputs/fhn2eqv2/window5
# [20:16:54] - [step:       1000] loss:  9.025e-04, time/iteration:  3.093e+01 ms
# [20:16:57] - [step:       1100] loss:  1.902e-03, time/iteration:  2.680e+01 ms
# [20:17:00] - [step:       1200] loss:  1.131e-04, time/iteration:  2.668e+01 ms
# [20:17:03] - [step:       1300] loss:  2.534e-04, time/iteration:  2.668e+01 ms
# [20:17:05] - [step:       1400] loss:  7.063e-04, time/iteration:  2.671e+01 ms
# [20:17:08] - [step:       1500] loss:  9.243e-05, time/iteration:  2.670e+01 ms
# [20:17:11] - [step:       1600] loss:  3.042e-04, time/iteration:  2.670e+01 ms
# [20:17:13] - [step:       1700] loss:  4.767e-04, time/iteration:  2.669e+01 ms
# [20:17:16] - [step:       1800] loss:  5.530e-05, time/iteration:  2.672e+01 ms
# [20:17:19] - [step:       1900] loss:  3.273e-04, time/iteration:  2.665e+01 ms
# [20:17:22] - [step:       2000] record constraint batch time:  4.333e-02s
# [20:17:22] - [step:       2000] record validators time:  4.189e-03s
# [20:17:22] - [step:       2000] saved checkpoint to outputs/fhn2eqv2/window5
# [20:17:22] - [step:       2000] loss:  7.739e-04, time/iteration:  3.093e+01 ms
# [20:17:24] - [step:       2100] loss:  1.819e-04, time/iteration:  2.685e+01 ms
# [20:17:27] - [step:       2200] loss:  4.090e-04, time/iteration:  2.671e+01 ms
# [20:17:30] - [step:       2300] loss:  2.837e-05, time/iteration:  2.672e+01 ms
# [20:17:32] - [step:       2400] loss:  2.891e-04, time/iteration:  2.670e+01 ms
# [20:17:35] - [step:       2500] loss:  4.841e-04, time/iteration:  2.673e+01 ms
# [20:17:38] - [step:       2600] loss:  1.620e-04, time/iteration:  2.670e+01 ms
# [20:17:40] - [step:       2700] loss:  4.516e-04, time/iteration:  2.674e+01 ms
# [20:17:43] - [step:       2800] loss:  2.064e-04, time/iteration:  2.693e+01 ms
# [20:17:46] - [step:       2900] loss:  4.232e-04, time/iteration:  2.676e+01 ms
# [20:17:49] - [step:       3000] record constraint batch time:  2.426e-02s
# [20:17:49] - [step:       3000] record validators time:  4.183e-03s
# [20:17:49] - [step:       3000] saved checkpoint to outputs/fhn2eqv2/window5
# [20:17:49] - [step:       3000] loss:  5.368e-04, time/iteration:  3.108e+01 ms
# [20:17:49] - [step:       3000] reached maximum training steps, finished training!
# [20:17:49] - Solving for Domain window6, iteration 0
# [20:17:49] - attempting to restore from: outputs/fhn2eqv2/window6
# [20:17:49] - optimizer checkpoint not found
# [20:17:49] - model network.0.pth not found
# [20:17:49] - [step:          0] record constraint batch time:  2.370e-02s
# [20:17:49] - [step:          0] record validators time:  4.154e-03s
# [20:17:49] - [step:          0] saved checkpoint to outputs/fhn2eqv2/window6
# [20:17:49] - [step:          0] loss:  2.760e-04
# [20:17:50] - Attempting cuda graph building, this may take a bit...
# [20:17:52] - [step:        100] loss:  2.171e-04, time/iteration:  3.037e+01 ms
# [20:17:55] - [step:        200] loss:  2.770e-04, time/iteration:  2.675e+01 ms
# [20:17:57] - [step:        300] loss:  1.862e-04, time/iteration:  2.677e+01 ms
# [20:18:00] - [step:        400] loss:  2.567e-04, time/iteration:  2.674e+01 ms
# [20:18:03] - [step:        500] loss:  2.003e-04, time/iteration:  2.675e+01 ms
# [20:18:06] - [step:        600] loss:  2.601e-04, time/iteration:  2.685e+01 ms
# [20:18:08] - [step:        700] loss:  1.973e-04, time/iteration:  2.682e+01 ms
# [20:18:11] - [step:        800] loss:  2.422e-04, time/iteration:  2.682e+01 ms
# [20:18:14] - [step:        900] loss:  2.661e-04, time/iteration:  2.684e+01 ms
# [20:18:17] - [step:       1000] record constraint batch time:  3.134e-02s
# [20:18:17] - [step:       1000] record validators time:  4.068e-03s
# [20:18:17] - [step:       1000] saved checkpoint to outputs/fhn2eqv2/window6
# [20:18:17] - [step:       1000] loss:  1.056e-04, time/iteration:  3.100e+01 ms
# [20:18:19] - [step:       1100] loss:  2.296e-04, time/iteration:  2.696e+01 ms
# [20:18:22] - [step:       1200] loss:  2.473e-04, time/iteration:  2.683e+01 ms
# [20:18:25] - [step:       1300] loss:  2.968e-04, time/iteration:  2.697e+01 ms
# [20:18:27] - [step:       1400] loss:  2.227e-04, time/iteration:  2.700e+01 ms
# [20:18:30] - [step:       1500] loss:  2.769e-04, time/iteration:  2.691e+01 ms
# [20:18:33] - [step:       1600] loss:  2.503e-04, time/iteration:  2.698e+01 ms
# [20:18:36] - [step:       1700] loss:  4.843e-04, time/iteration:  2.687e+01 ms
# [20:18:38] - [step:       1800] loss:  2.622e-04, time/iteration:  2.685e+01 ms
# [20:18:41] - [step:       1900] loss:  2.402e-04, time/iteration:  2.687e+01 ms
# [20:18:44] - [step:       2000] record constraint batch time:  4.318e-02s
# [20:18:44] - [step:       2000] record validators time:  4.317e-03s
# [20:18:44] - [step:       2000] saved checkpoint to outputs/fhn2eqv2/window6
# [20:18:44] - [step:       2000] loss:  2.647e-04, time/iteration:  3.104e+01 ms
# [20:18:47] - [step:       2100] loss:  2.482e-04, time/iteration:  2.700e+01 ms
# [20:18:49] - [step:       2200] loss:  3.039e-04, time/iteration:  2.689e+01 ms
# [20:18:52] - [step:       2300] loss:  2.382e-04, time/iteration:  2.692e+01 ms
# [20:18:55] - [step:       2400] loss:  2.683e-04, time/iteration:  2.691e+01 ms
# [20:18:57] - [step:       2500] loss:  2.186e-04, time/iteration:  2.692e+01 ms
# [20:19:00] - [step:       2600] loss:  2.645e-04, time/iteration:  2.705e+01 ms
# [20:19:03] - [step:       2700] loss:  2.221e-04, time/iteration:  2.697e+01 ms
# [20:19:06] - [step:       2800] loss:  2.575e-04, time/iteration:  2.702e+01 ms
# [20:19:08] - [step:       2900] loss:  1.938e-04, time/iteration:  2.694e+01 ms
# [20:19:11] - [step:       3000] record constraint batch time:  2.453e-02s
# [20:19:11] - [step:       3000] record validators time:  4.162e-03s
# [20:19:11] - [step:       3000] saved checkpoint to outputs/fhn2eqv2/window6
# [20:19:11] - [step:       3000] loss:  2.615e-04, time/iteration:  3.107e+01 ms
# [20:19:11] - [step:       3000] reached maximum training steps, finished training!
# [20:19:11] - Solving for Domain window7, iteration 0
# [20:19:11] - attempting to restore from: outputs/fhn2eqv2/window7
# [20:19:11] - optimizer checkpoint not found
# [20:19:11] - model network.0.pth not found
# [20:19:12] - [step:          0] record constraint batch time:  2.358e-02s
# [20:19:12] - [step:          0] record validators time:  4.126e-03s
# [20:19:12] - [step:          0] saved checkpoint to outputs/fhn2eqv2/window7
# [20:19:12] - [step:          0] loss:  2.723e-04
# [20:19:12] - Attempting cuda graph building, this may take a bit...
# [20:19:15] - [step:        100] loss:  2.570e-04, time/iteration:  3.075e+01 ms
# [20:19:17] - [step:        200] loss:  2.181e-04, time/iteration:  2.695e+01 ms
# [20:19:20] - [step:        300] loss:  3.425e-04, time/iteration:  2.697e+01 ms
# [20:19:23] - [step:        400] loss:  2.489e-04, time/iteration:  2.720e+01 ms
# [20:19:26] - [step:        500] loss:  2.706e-04, time/iteration:  2.707e+01 ms
# [20:19:28] - [step:        600] loss:  2.205e-04, time/iteration:  2.709e+01 ms
# [20:19:31] - [step:        700] loss:  2.704e-04, time/iteration:  2.708e+01 ms
# [20:19:34] - [step:        800] loss:  2.272e-04, time/iteration:  2.699e+01 ms
# [20:19:36] - [step:        900] loss:  3.298e-04, time/iteration:  2.706e+01 ms
# [20:19:39] - [step:       1000] record constraint batch time:  3.101e-02s
# [20:19:39] - [step:       1000] record validators time:  4.124e-03s
# [20:19:39] - [step:       1000] saved checkpoint to outputs/fhn2eqv2/window7
# [20:19:39] - [step:       1000] loss:  2.519e-04, time/iteration:  3.117e+01 ms
# [20:19:42] - [step:       1100] loss:  4.541e-04, time/iteration:  2.719e+01 ms
# [20:19:45] - [step:       1200] loss:  2.483e-04, time/iteration:  2.706e+01 ms
# [20:19:48] - [step:       1300] loss:  2.131e-04, time/iteration:  2.709e+01 ms
# [20:19:50] - [step:       1400] loss:  2.665e-04, time/iteration:  2.708e+01 ms
# [20:19:53] - [step:       1500] loss:  2.621e-04, time/iteration:  2.706e+01 ms
# [20:19:56] - [step:       1600] loss:  2.584e-04, time/iteration:  2.714e+01 ms
# [20:19:58] - [step:       1700] loss:  2.330e-04, time/iteration:  2.715e+01 ms
# [20:20:01] - [step:       1800] loss:  2.238e-04, time/iteration:  2.713e+01 ms
# [20:20:04] - [step:       1900] loss:  2.635e-04, time/iteration:  2.729e+01 ms
# [20:20:07] - [step:       2000] record constraint batch time:  4.398e-02s
# [20:20:07] - [step:       2000] record validators time:  4.271e-03s
# [20:20:07] - [step:       2000] saved checkpoint to outputs/fhn2eqv2/window7
# [20:20:07] - [step:       2000] loss:  2.606e-04, time/iteration:  3.181e+01 ms
# [20:20:10] - [step:       2100] loss:  2.511e-04, time/iteration:  2.737e+01 ms
# [20:20:13] - [step:       2200] loss:  2.898e-04, time/iteration:  2.731e+01 ms
# [20:20:15] - [step:       2300] loss:  2.055e-04, time/iteration:  2.723e+01 ms
# [20:20:18] - [step:       2400] loss:  2.536e-04, time/iteration:  2.720e+01 ms
# [20:20:21] - [step:       2500] loss:  2.563e-03, time/iteration:  2.722e+01 ms
# [20:20:23] - [step:       2600] loss:  2.623e-04, time/iteration:  2.722e+01 ms
# [20:20:26] - [step:       2700] loss:  2.594e-04, time/iteration:  2.725e+01 ms
# [20:20:29] - [step:       2800] loss:  2.041e-04, time/iteration:  2.725e+01 ms
# [20:20:32] - [step:       2900] loss:  2.787e-04, time/iteration:  2.726e+01 ms
# [20:20:35] - [step:       3000] record constraint batch time:  2.445e-02s
# [20:20:35] - [step:       3000] record validators time:  4.393e-03s
# [20:20:35] - [step:       3000] saved checkpoint to outputs/fhn2eqv2/window7
# [20:20:35] - [step:       3000] loss:  2.622e-04, time/iteration:  3.140e+01 ms
# [20:20:35] - [step:       3000] reached maximum training steps, finished training!
# [20:20:35] - Solving for Domain window8, iteration 0
# [20:20:35] - attempting to restore from: outputs/fhn2eqv2/window8
# [20:20:35] - optimizer checkpoint not found
# [20:20:35] - model network.0.pth not found
# [20:20:35] - [step:          0] record constraint batch time:  2.345e-02s
# [20:20:35] - [step:          0] record validators time:  4.291e-03s
# [20:20:35] - [step:          0] saved checkpoint to outputs/fhn2eqv2/window8
# [20:20:35] - [step:          0] loss:  2.578e-04
# [20:20:36] - Attempting cuda graph building, this may take a bit...
# [20:20:38] - [step:        100] loss:  2.519e-04, time/iteration:  3.116e+01 ms
# [20:20:41] - [step:        200] loss:  2.764e-04, time/iteration:  2.729e+01 ms
# [20:20:44] - [step:        300] loss:  2.252e-04, time/iteration:  2.730e+01 ms
# [20:20:46] - [step:        400] loss:  2.455e-04, time/iteration:  2.726e+01 ms
# [20:20:49] - [step:        500] loss:  2.680e-04, time/iteration:  2.731e+01 ms
# [20:20:52] - [step:        600] loss:  2.214e-04, time/iteration:  2.734e+01 ms
# [20:20:55] - [step:        700] loss:  2.492e-04, time/iteration:  2.731e+01 ms
# [20:20:57] - [step:        800] loss:  2.566e-04, time/iteration:  2.731e+01 ms
# [20:21:00] - [step:        900] loss:  2.528e-04, time/iteration:  2.732e+01 ms
# [20:21:03] - [step:       1000] record constraint batch time:  3.079e-02s
# [20:21:03] - [step:       1000] record validators time:  4.067e-03s
# [20:21:03] - [step:       1000] saved checkpoint to outputs/fhn2eqv2/window8
# [20:21:03] - [step:       1000] loss:  2.663e-04, time/iteration:  3.152e+01 ms
# [20:21:06] - [step:       1100] loss:  2.546e-04, time/iteration:  2.745e+01 ms
# [20:21:09] - [step:       1200] loss:  2.490e-04, time/iteration:  2.733e+01 ms
# [20:21:11] - [step:       1300] loss:  3.239e-04, time/iteration:  2.733e+01 ms
# [20:21:14] - [step:       1400] loss:  2.417e-04, time/iteration:  2.738e+01 ms
# [20:21:17] - [step:       1500] loss:  2.583e-04, time/iteration:  2.745e+01 ms
# [20:21:20] - [step:       1600] loss:  2.507e-04, time/iteration:  2.764e+01 ms
# [20:21:22] - [step:       1700] loss:  2.541e-04, time/iteration:  2.745e+01 ms
# [20:21:25] - [step:       1800] loss:  8.168e-04, time/iteration:  2.750e+01 ms
# [20:21:28] - [step:       1900] loss:  2.522e-04, time/iteration:  2.739e+01 ms
# [20:21:31] - [step:       2000] record constraint batch time:  4.382e-02s
# [20:21:31] - [step:       2000] record validators time:  4.055e-03s
# [20:21:31] - [step:       2000] saved checkpoint to outputs/fhn2eqv2/window8
# [20:21:31] - [step:       2000] loss:  2.537e-04, time/iteration:  3.166e+01 ms
# [20:21:34] - [step:       2100] loss:  2.819e-04, time/iteration:  2.757e+01 ms
# [20:21:37] - [step:       2200] loss:  2.556e-04, time/iteration:  2.766e+01 ms
# [20:21:39] - [step:       2300] loss:  2.501e-04, time/iteration:  2.759e+01 ms
# [20:21:42] - [step:       2400] loss:  2.582e-04, time/iteration:  2.761e+01 ms
# [20:21:45] - [step:       2500] loss:  2.461e-04, time/iteration:  2.753e+01 ms
# [20:21:48] - [step:       2600] loss:  2.569e-04, time/iteration:  2.745e+01 ms
# [20:21:50] - [step:       2700] loss:  2.563e-04, time/iteration:  2.748e+01 ms
# [20:21:53] - [step:       2800] loss:  5.866e-04, time/iteration:  2.748e+01 ms
# [20:21:56] - [step:       2900] loss:  2.445e-04, time/iteration:  2.755e+01 ms
# [20:21:59] - [step:       3000] record constraint batch time:  2.451e-02s
# [20:21:59] - [step:       3000] record validators time:  4.196e-03s
# [20:21:59] - [step:       3000] saved checkpoint to outputs/fhn2eqv2/window8
# [20:21:59] - [step:       3000] loss:  2.558e-04, time/iteration:  3.187e+01 ms
# [20:21:59] - [step:       3000] reached maximum training steps, finished training!
# [20:21:59] - Solving for Domain window9, iteration 0
# [20:21:59] - attempting to restore from: outputs/fhn2eqv2/window9
# [20:21:59] - optimizer checkpoint not found
# [20:21:59] - model network.0.pth not found
# [20:21:59] - [step:          0] record constraint batch time:  2.385e-02s
# [20:21:59] - [step:          0] record validators time:  4.202e-03s
# [20:21:59] - [step:          0] saved checkpoint to outputs/fhn2eqv2/window9
# [20:21:59] - [step:          0] loss:  2.544e-04
# [20:22:00] - Attempting cuda graph building, this may take a bit...
# [20:22:02] - [step:        100] loss:  2.457e-04, time/iteration:  3.168e+01 ms
# [20:22:05] - [step:        200] loss:  1.983e-04, time/iteration:  2.756e+01 ms
# [20:22:08] - [step:        300] loss:  2.489e-04, time/iteration:  2.755e+01 ms
# [20:22:11] - [step:        400] loss:  2.114e-04, time/iteration:  2.772e+01 ms
# [20:22:13] - [step:        500] loss:  2.527e-04, time/iteration:  2.766e+01 ms
# [20:22:16] - [step:        600] loss:  2.851e-04, time/iteration:  2.767e+01 ms
# [20:22:19] - [step:        700] loss:  2.449e-04, time/iteration:  2.758e+01 ms
# [20:22:22] - [step:        800] loss:  2.522e-04, time/iteration:  2.755e+01 ms
# [20:22:25] - [step:        900] loss:  1.929e-03, time/iteration:  2.760e+01 ms
# [20:22:28] - [step:       1000] record constraint batch time:  3.108e-02s
# [20:22:28] - [step:       1000] record validators time:  4.056e-03s
# [20:22:28] - [step:       1000] saved checkpoint to outputs/fhn2eqv2/window9
# [20:22:28] - [step:       1000] loss:  2.393e-04, time/iteration:  3.180e+01 ms
# [20:22:30] - [step:       1100] loss:  3.199e-04, time/iteration:  2.773e+01 ms
# [20:22:33] - [step:       1200] loss:  4.020e-04, time/iteration:  2.759e+01 ms
# [20:22:36] - [step:       1300] loss:  2.509e-04, time/iteration:  2.760e+01 ms
# [20:22:39] - [step:       1400] loss:  2.189e-04, time/iteration:  2.772e+01 ms
# [20:22:42] - [step:       1500] loss:  2.521e-04, time/iteration:  2.776e+01 ms
# [20:22:44] - [step:       1600] loss:  2.389e-04, time/iteration:  2.771e+01 ms
# [20:22:47] - [step:       1700] loss:  3.617e-04, time/iteration:  2.773e+01 ms
# [20:22:50] - [step:       1800] loss:  2.524e-04, time/iteration:  2.760e+01 ms
# [20:22:53] - [step:       1900] loss:  2.458e-04, time/iteration:  2.765e+01 ms
# [20:22:56] - [step:       2000] record constraint batch time:  4.354e-02s
# [20:22:56] - [step:       2000] record validators time:  4.210e-03s
# [20:22:56] - [step:       2000] saved checkpoint to outputs/fhn2eqv2/window9
# [20:22:56] - [step:       2000] loss:  1.022e-03, time/iteration:  3.189e+01 ms
# [20:22:59] - [step:       2100] loss:  2.517e-04, time/iteration:  2.776e+01 ms
# [20:23:01] - [step:       2200] loss:  2.362e-04, time/iteration:  2.764e+01 ms
# [20:23:04] - [step:       2300] loss:  2.624e-04, time/iteration:  2.766e+01 ms
# [20:23:07] - [step:       2400] loss:  2.409e-04, time/iteration:  2.769e+01 ms
# [20:23:10] - [step:       2500] loss:  2.600e-04, time/iteration:  2.786e+01 ms
# [20:23:12] - [step:       2600] loss:  2.456e-04, time/iteration:  2.769e+01 ms
# [20:23:15] - [step:       2700] loss:  2.570e-04, time/iteration:  2.785e+01 ms
# [20:23:18] - [step:       2800] loss:  2.434e-04, time/iteration:  2.767e+01 ms
# [20:23:21] - [step:       2900] loss:  2.555e-04, time/iteration:  2.765e+01 ms
# [20:23:24] - [step:       3000] record constraint batch time:  2.463e-02s
# [20:23:24] - [step:       3000] record validators time:  4.197e-03s
# [20:23:24] - [step:       3000] saved checkpoint to outputs/fhn2eqv2/window9
# [20:23:24] - [step:       3000] loss:  2.497e-04, time/iteration:  3.184e+01 ms
# [20:23:24] - [step:       3000] reached maximum training steps, finished training!
