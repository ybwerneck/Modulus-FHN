# %%
# %%writefile conf/config.yaml
# # Arch	                        Start Lr	Max Steps	Decay Steps
# # FullyConnectedArch	        1.00E-03	1500000	        15000
# # FourierNetArch                1.00E-03	400000	        7500
# # ModifiedFourierNetArch 	1.00E-03	400000	        7500
# # SirenArch                     2.00E-05	500000	        5000
# # DGMArch                       1.00E-03        1500000         15000
#
# # WARNING: Setting "exact_continuity" to true or setting the arch
# # as "ModifiedFourierNetArch" increases the memory requirements of the
# # problem. Batchsizes may need to be reduced for such cases.
#
# defaults :
#   - modulus_default
#   - arch:
#       - fully_connected
#   - scheduler: exponential_lr
#   - optimizer: adam
#   - loss: sum
#   - _self_
#
# jit: false
#
#
# training:
#   rec_results_freq : 1000
#   rec_constraint_freq: 2000
#   max_steps : 2000
#
# batch_size:
#   initial_condition: 4096
#   interior: 4096
# Out:
# Overwriting conf/config.yaml

# %%
# %%writefile fhn2SIM.py
from modulus.models.fully_connected import FullyConnectedArch
from modulus.models.fourier_net import FourierNetArch
from modulus.models.siren import SirenArch
from modulus.models.modified_fourier_net import ModifiedFourierNetArch
from modulus.models.dgm import DGMArch

from sympy import Symbol, Eq
from sympy import Symbol, Function, Number
from modulus.eq.pde import PDE
import numpy as np
import matplotlib.pyplot as plt
from scipy import interpolate
import modulus
from modulus.hydra import instantiate_arch, ModulusConfig
from modulus.solver import Solver
from modulus.domain import Domain
from modulus.geometry.primitives_1d import Point1D
from modulus.domain.constraint import (
    PointwiseBoundaryConstraint,
    PointwiseInteriorConstraint,
)
from modulus.domain.validator import PointwiseValidator
from modulus.key import Key
from modulus.node import Node
from modulus.eq.pde import PDE
from modulus.geometry import Parameterization
from sympy import Symbol, Eq, Abs, tanh, Or, And
from modulus.utils.io import (
    csv_to_dict,
    ValidatorPlotter,
    InferencerPlotter,
)
from modulus.solver import SequentialSolver

from modulus.models.deeponet import DeepONetArch
from modulus.domain.constraint.continuous import DeepONetConstraint
from modulus.models.moving_time_window import MovingTimeWindowArch
from modulus.domain.monitor import Monitor
from modulus.domain.constraint import Constraint
from modulus.graph import Graph
from modulus.key import Key
from modulus.constants import TF_SUMMARY
from modulus.distributed import DistributedManager
from modulus.utils.io import dict_to_csv, csv_to_dict
from modulus.domain.inferencer.pointwise import PointwiseInferencer as PointwiseInferencer

class MONI(Monitor):
    """
    Pointwise Inferencer that allows inferencing on pointwise data

    Parameters
    ----------
    invar : Dict[str, np.ndarray (N, 1)]
        Dictionary of numpy arrays as input.
    output_names : List[str]
        List of outputs needed for metric.
    metrics : Dict[str, Callable]
        Dictionary of pytorch functions whose input is a dictionary
        torch tensors whose keys are the `output_names`. The keys
        to `metrics` will be used to label the metrics in tensorboard/csv outputs.
    nodes : List[Node]
        List of Modulus Nodes to unroll graph with.
    requires_grad : bool = False
        If automatic differentiation is needed for computing results.
    """

    def __init__(self, invar, output_names, metrics, nodes, requires_grad=False):

        # construct model from nodes
        self.requires_grad = requires_grad
        self.model = Graph(
            nodes, Key.convert_list(invar.keys()), Key.convert_list(output_names)
        )
        self.manager = DistributedManager()
        self.device = self.manager.device
        self.model.to(self.device)

        # set metrics
        self.metrics = metrics
        self.monitor_outvar_store = {}

        # set invar
        self.invar = Constraint._set_device(invar, device=self.device)

    def save_results(self, name, writer, step, data_dir):
        plt.clf()
        # run forward inference
        invar = Constraint._set_device(
            self.invar, device=self.device, requires_grad=self.requires_grad
        )
        outvar = self.model(invar)
        metrics = {key: func({**invar, **outvar}) for key, func in self.metrics.items()}
        t=metrics["t"].detach().cpu().numpy()
        x1=metrics["x1"].detach().cpu().numpy()
        odex1=metrics["ode_x1"].detach().cpu().numpy()
        plt.scatter(t,x1)
        
        plt.savefig(data_dir+"x1s"+str(step)+".png")
        plt.clf()
        plt.scatter(t,odex1)
       # print(t)

        
        plt.savefig(data_dir+"ode_x1s"+str(step)+".png")
       
        return metrics

    
t_max = 10.0
n_w=10   
t_w= t_max/n_w
def generateExactSolution(t,dt,x0,rate,P,begin,end):
    
    
    n2=int(t/(dt))+2
    n = int((end-begin)/(dt*rate))
    Sol=np.zeros((n,3))
  
    Sol2=np.zeros((n2,2))
    Sol2[0]=x0,0
    T=0
    k=0
    while(k<n2-1):
        x,w=Sol2[k]
        Sol2[k+1]=10*(x*(x-0.4)*(1-x)-w)*dt+  x, 0.5*(x*0.2-0.8*w)*dt +w
 
        if ((k*dt==begin or ((k+1)%rate == 0 and k*dt>=begin and k*dt<=end))and T<n):
          
           
            Sol[T] = Sol2[k][0],Sol2[k][1] , k*dt
            T=T+1
        
        k=k+1
        if(k*dt > end):
            break
    return Sol

def generateValidator(w_i,nodes):

    
    
    T=np.empty([0])
    K=np.empty([0])
    SOLs=np.empty([0])
    SOLw=np.empty([0])
    krange= [(0 + 0.05*i*1) for i in range(0,20)]

    deltaT = 0.01
    
    rate=1
    for KR in krange:
        begin=w_i* t_w
        end=begin + t_w
        sol=generateExactSolution(t_max,deltaT,KR,rate,KR,begin,end)
        
        T=np.append(T,sol.T[2] - begin)
        K = np.append(K,np.full_like (sol.T[2],KR))
        SOLs=np.append(SOLs,sol.T[0])
        SOLw=np.append(SOLw,sol.T[1])
    
    
    t = np.expand_dims(T, axis=-1)


    k = np.expand_dims(K, axis=-1)

    
    Solx = np.expand_dims(SOLs, axis=-1)

    
    Solw = np.expand_dims(SOLw, axis=-1)
   
    
    print(t,"val set de ",begin,"a ", end)

    
    invar_numpy = {"t": t,"K":k}
    outvar_numpy = {
        "x1": Solx,
        "w":Solw
    }
   
    validator = PointwiseValidator(
        nodes=nodes, invar=invar_numpy, true_outvar=outvar_numpy, batch_size=1024,plotter=ValidatorPlotter()
    )
    return validator

def generateDataC(w_i,nodes):

    
    
    T=np.empty([0])
    K=np.empty([0])
    SOLs=np.empty([0])
    SOLw=np.empty([0])
    krange= [(0.01 + 0.06*i*1) for i in range(0,20)]

    deltaT = 0.01
    
    rate=1
    for KR in krange:
        begin=w_i* t_w
        end=begin + t_w
        sol=generateExactSolution(t_max,deltaT,KR,rate,KR,begin,end)
        
        T=np.append(T,sol.T[2] - begin)
        K = np.append(K,np.full_like (sol.T[2],KR))
        SOLs=np.append(SOLs,sol.T[0])
        SOLw=np.append(SOLw,sol.T[1])
    
    
    t = np.expand_dims(T, axis=-1)


    k = np.expand_dims(K, axis=-1)

    
    Solx = np.expand_dims(SOLs, axis=-1)

    
    Solw = np.expand_dims(SOLw, axis=-1)
   
    
    print(t,"val set de ",begin,"a ", end)

    
    invar_numpy = {"t": t,"K":k}
    outvar_numpy = {
        "x1": Solx,
        "w":Solw
    }
   
    data = DeepONetConstraint.from_numpy(
        nodes=nodes,
        invar=invar_numpy,
        outvar=outvar_numpy,
        batch_size=1000,
        lambda_weighting=None
    )
    return data


class SpringMass(PDE):
    name = "SpringMass"

    def __init__(self):

        t = Symbol("t")
       
        input_variables = {"t": t}

        x = Function("x1")(*input_variables)
        w= Function("w")(*input_variables)
        self.equations = {}
        self.equations["ode_x1"] =10*(x*(x-0.4)*(1-x)-w) -x.diff(t)
        self.equations["ode_w"]  =0.5*(x*0.2-0.8*w) -w.diff(t)
        
@modulus.main(config_path="conf", config_name="config")
def run(cfg: ModulusConfig) -> None:
    
    # make list of nodes to unroll graph on
    sm = SpringMass()
    sm.pprint()
    #sm_net = FullyConnectedArch(
    #    input_keys=[Key("t"), Key("K")],
    #    output_keys=[Key("x1")],
    #)
    #nodes = sm.make_nodes() + [
    #    sm_net.make_node(name="network")
    #]


    
    # make list of nodes to unroll graph on
    sm = SpringMass()
    sm.pprint()
    #sm_net = FullyConnectedArch(
    #    input_keys=[Key("t"), Key("K")],
    #    output_keys=[Key("x1")],
    #)
    #nodes = sm.make_nodes() + [
    #    sm_net.make_node(name="network")
    #]

    
    
    flow_net = FullyConnectedArch(
            input_keys=[Key("t"), Key("K") ],
            output_keys=[Key("x1"),Key("w")],
            layer_size=300,
            nr_layers=10,
        )

    

    time_window_net = MovingTimeWindowArch(flow_net, t_w)

    nodes = sm.make_nodes() +[time_window_net.make_node(name="network")]


    for node in nodes:
        print(node.__str__())
   
    # add constraints to solver
    # make geometry
    geo = Point1D(0)
    
    t_symbol = Symbol("t")
    x_symbol = Symbol("x1")
    k_symbol= Symbol("K")
    time_range = {t_symbol: (0,t_w )}
    k_range= {k_symbol:(0,1)}
    tr = {t_symbol: (0, t_w)}

    # make domain
        # make initial condition domain
    ic_domain = Domain("initial_conditions")

  
    # initial conditions
    IC = PointwiseBoundaryConstraint(
        nodes=nodes,
        geometry=geo,
        outvar={"x1": k_symbol,"w":0},
        batch_size=2000,
        parameterization={**{t_symbol:0},**k_range},
        lambda_weighting={
            "x1": 100,# + 1000*x_symbol.diff(t_symbol)*x_symbol.diff(t_symbol),
            "w": 100 #+ 1000*x_symbol.diff(t_symbol)*x_symbol.diff(t_symbol)
        },
        
        quasirandom=True,
    )

    ic_domain.add_constraint(IC, name="IC")
    
        # solve over given time period
    interior = PointwiseBoundaryConstraint(
        nodes=nodes,
        geometry=geo,
        outvar={"ode_x1": 0.0,"ode_w":0.0},
        batch_size=1000,
        parameterization={**tr,**k_range},
        #criteria=And(t_symbol > 0, t_symbol < 3),
        lambda_weighting={
            "ode_x1": 100,# + 1000*x_symbol.diff(t_symbol)*x_symbol.diff(t_symbol),
            "ode_w": 100 #+ 1000*x_symbol.diff(t_symbol)*x_symbol.diff(t_symbol)
        },
        quasirandom=True,
    )
    ic_domain.add_constraint(interior, name="interior")

    
    
    
    domains=[]
    for i in range(1,n_w):

        # make moving window domain
        window_domain = Domain("window"+str(i))

        # solve over given time period
        interior1 = PointwiseBoundaryConstraint(
        nodes=nodes,
        geometry=geo,
        outvar={"ode_x1": 0.0,"ode_w":0.0},
        batch_size=2000,
        parameterization={**tr,**k_range},
        #criteria=And(t_symbol > 0, t_symbol < 3),
        lambda_weighting={
            "ode_x1": 100,# + 1000*x_symbol.diff(t_symbol)*x_symbol.diff(t_symbol),
            "ode_w": 100 #+ 1000*x_symbol.diff(t_symbol)*x_symbol.diff(t_symbol)
        },
        quasirandom=True,

        )
        interior2 = PointwiseBoundaryConstraint(
        nodes=nodes,
        geometry=geo,
        outvar={"ode_x1": 0.0,"ode_w":0.0},
        batch_size=1000,
        parameterization={**tr,**{k_symbol:(0.45,0.6)}},
        #criteria=And(t_symbol > 0, t_symbol < 3),
        lambda_weighting={
            "ode_x1": 200,# + 1000*x_symbol.diff(t_symbol)*x_symbol.diff(t_symbol),
            "ode_w": 200 #+ 1000*x_symbol.diff(t_symbol)*x_symbol.diff(t_symbol)
        },
        quasirandom=True,

        )
        
        
        IC = PointwiseBoundaryConstraint(
        nodes=nodes,
        geometry=geo,
        outvar={"x1_prev_step_diff":0,"w_prev_step_diff":0},
        batch_size=500,
        parameterization={**{t_symbol:0},**k_range},
        lambda_weighting={
            "x1_prev_step_diff": 1000,
            "w_prev_step_diff": 1000
        },
        
        quasirandom=True,
    )
        
    
        
        window_domain.add_constraint(IC, name="IC")
        window_domain.add_constraint(interior1, "interior")
        #window_domain.add_constraint(interior2, "interiorTr")

        domains.append(window_domain)
    

    
 
    
    

    
    dom=[]
    dom.append((1,ic_domain))

    for domain in domains:
        dom.append((1,domain))
    print(cfg)
    # make solver
    #slv = Solver(cfg, domain)
    #print(domains)
    i=0
    for a,d in dom:
        print(d)
        print(d.name)
        d.add_validator(generateValidator(i,nodes))
        d.add_constraint(generateDataC(i,nodes))
        i=i+1
    
      
    slv = SequentialSolver(
        cfg,
        dom,
        custom_update_operation=time_window_net.move_window,


    )

    # start solver
    slv.solve()

        
        
        
if __name__ == "__main__":
    run()
# Out:
# Overwriting fhn2SIM.py

# %%
# !rm -r outputs/fhn2SIM || true ##se não limpar o output ele aproveita o treinamento, mesmo se mudar o modelo
# !python fhn2SIM.py
# Out:
# rm: cannot remove 'outputs/fhn2SIM': No such file or directory
# [03:08:10] - JitManager: {'_enabled': False, '_arch_mode': <JitArchMode.ONLY_ACTIVATION: 1>, '_use_nvfuser': True, '_autograd_nodes': False}
# [03:08:10] - GraphManager: {'_func_arch': False, '_debug': False, '_func_arch_allow_partial_hessian': True}
# ode_x1: 10*(1 - x1)*(x1 - 0.4)*x1 - 10*w - x1__t
# ode_w: -0.4*w + 0.1*x1 - w__t
# ode_x1: 10*(1 - x1)*(x1 - 0.4)*x1 - 10*w - x1__t
# ode_w: -0.4*w + 0.1*x1 - w__t
# node: Sympy Node: ode_x1
# evaluate: SympyToTorch
# inputs: [w, x1]
# derivatives: [x1__t]
# outputs: [ode_x1]
# optimize: False
# node: Sympy Node: ode_w
# evaluate: SympyToTorch
# inputs: [w, x1]
# derivatives: [w__t]
# outputs: [ode_w]
# optimize: False
# node: Arch Node: network
# evaluate: MovingTimeWindowArch
# inputs: [t, K]
# derivatives: []
# outputs: [x1, w, x1_prev_step, w_prev_step, x1_prev_step_diff, w_prev_step_diff]
# optimize: True
# {'training': {'max_steps': 2000, 'grad_agg_freq': 1, 'rec_results_freq': 1000, 'rec_validation_freq': '${training.rec_results_freq}', 'rec_inference_freq': '${training.rec_results_freq}', 'rec_monitor_freq': '${training.rec_results_freq}', 'rec_constraint_freq': 2000, 'save_network_freq': 1000, 'print_stats_freq': 100, 'summary_freq': 1000, 'amp': False, 'amp_dtype': 'float16', 'ntk': {'use_ntk': False, 'save_name': None, 'run_freq': 1000}}, 'graph': {'func_arch': False, 'func_arch_allow_partial_hessian': True}, 'stop_criterion': {'metric': None, 'min_delta': None, 'patience': 50000, 'mode': 'min', 'freq': 1000, 'strict': False}, 'profiler': {'profile': False, 'start_step': 0, 'end_step': 100, 'name': 'nvtx'}, 'network_dir': '.', 'initialization_network_dir': '', 'save_filetypes': 'vtk', 'summary_histograms': False, 'jit': False, 'jit_use_nvfuser': True, 'jit_arch_mode': 'only_activation', 'jit_autograd_nodes': False, 'cuda_graphs': True, 'cuda_graph_warmup': 20, 'find_unused_parameters': False, 'broadcast_buffers': False, 'device': '', 'debug': False, 'run_mode': 'train', 'arch': {'fully_connected': {'arch_type': 'fully_connected', 'input_keys': '???', 'output_keys': '???', 'detach_keys': '???', 'scaling': None, 'layer_size': 512, 'nr_layers': 6, 'skip_connections': False, 'activation_fn': 'silu', 'adaptive_activations': False, 'weight_norm': True}}, 'models': '???', 'loss': {'_target_': 'modulus.loss.aggregator.Sum', 'weights': None}, 'optimizer': {'_params_': {'compute_gradients': 'adam_compute_gradients', 'apply_gradients': 'adam_apply_gradients'}, '_target_': 'torch.optim.Adam', 'lr': 0.001, 'betas': [0.9, 0.999], 'eps': 1e-08, 'weight_decay': 0.0, 'amsgrad': False}, 'scheduler': {'_target_': 'torch.optim.lr_scheduler.ExponentialLR', 'gamma': 0.99998718}, 'batch_size': {'initial_condition': 4096, 'interior': 4096}, 'custom': '???'}
# <modulus.domain.domain.Domain object at 0x7f8fc718a8b0>
# initial_conditions
# [[0.  ]
#  [0.01]
#  [0.02]
#  ...
#  [0.97]
#  [0.98]
#  [0.99]] val set de  0.0 a  1.0
# [[0.  ]
#  [0.01]
#  [0.02]
#  ...
#  [0.97]
#  [0.98]
#  [0.99]] val set de  0.0 a  1.0
# <modulus.domain.domain.Domain object at 0x7f8fc718a9a0>
# window1
# [[0.  ]
#  [0.01]
#  [0.02]
#  ...
#  [0.97]
#  [0.98]
#  [0.99]] val set de  1.0 a  2.0
# [[0.  ]
#  [0.01]
#  [0.02]
#  ...
#  [0.97]
#  [0.98]
#  [0.99]] val set de  1.0 a  2.0
# <modulus.domain.domain.Domain object at 0x7f8fc717be80>
# window2
# [[0.  ]
#  [0.01]
#  [0.02]
#  ...
#  [0.97]
#  [0.98]
#  [0.99]] val set de  2.0 a  3.0
# [[0.  ]
#  [0.01]
#  [0.02]
#  ...
#  [0.97]
#  [0.98]
#  [0.99]] val set de  2.0 a  3.0
# <modulus.domain.domain.Domain object at 0x7f8fc7182d00>
# window3
# [[0.  ]
#  [0.01]
#  [0.02]
#  ...
#  [0.97]
#  [0.98]
#  [0.99]] val set de  3.0 a  4.0
# [[0.  ]
#  [0.01]
#  [0.02]
#  ...
#  [0.97]
#  [0.98]
#  [0.99]] val set de  3.0 a  4.0
# <modulus.domain.domain.Domain object at 0x7f8fc713c6d0>
# window4
# [[0.  ]
#  [0.01]
#  [0.02]
#  ...
#  [0.97]
#  [0.98]
#  [0.99]] val set de  4.0 a  5.0
# [[0.  ]
#  [0.01]
#  [0.02]
#  ...
#  [0.97]
#  [0.98]
#  [0.99]] val set de  4.0 a  5.0
# <modulus.domain.domain.Domain object at 0x7f8fc7148670>
# window5
# [[0.  ]
#  [0.01]
#  [0.02]
#  ...
#  [0.97]
#  [0.98]
#  [0.99]] val set de  5.0 a  6.0
# [[0.  ]
#  [0.01]
#  [0.02]
#  ...
#  [0.97]
#  [0.98]
#  [0.99]] val set de  5.0 a  6.0
# <modulus.domain.domain.Domain object at 0x7f8fc71537c0>
# window6
# [[0.  ]
#  [0.01]
#  [0.02]
#  ...
#  [0.97]
#  [0.98]
#  [0.99]] val set de  6.0 a  7.0
# [[0.  ]
#  [0.01]
#  [0.02]
#  ...
#  [0.97]
#  [0.98]
#  [0.99]] val set de  6.0 a  7.0
# <modulus.domain.domain.Domain object at 0x7f8fc715b910>
# window7
# [[0.  ]
#  [0.01]
#  [0.02]
#  ...
#  [0.97]
#  [0.98]
#  [0.99]] val set de  7.0 a  8.0
# [[0.  ]
#  [0.01]
#  [0.02]
#  ...
#  [0.97]
#  [0.98]
#  [0.99]] val set de  7.0 a  8.0
# <modulus.domain.domain.Domain object at 0x7f8fc7166a60>
# window8
# [[0.  ]
#  [0.01]
#  [0.02]
#  ...
#  [0.97]
#  [0.98]
#  [0.99]] val set de  8.0 a  9.0
# [[0.  ]
#  [0.01]
#  [0.02]
#  ...
#  [0.97]
#  [0.98]
#  [0.99]] val set de  8.0 a  9.0
# <modulus.domain.domain.Domain object at 0x7f8fc7166700>
# window9
# [[0.  ]
#  [0.01]
#  [0.02]
#  ...
#  [0.97]
#  [0.98]
#  [0.99]] val set de  9.0 a  10.0
# [[0.  ]
#  [0.01]
#  [0.02]
#  ...
#  [0.97]
#  [0.98]
#  [0.99]] val set de  9.0 a  10.0
# [03:08:18] - Solving for Domain initial_conditions, iteration 0
# [03:08:18] - attempting to restore from: outputs/fhn2SIM/initial_conditions
# [03:08:18] - optimizer checkpoint not found
# [03:08:18] - model network.0.pth not found
# [03:08:19] - [step:          0] record constraint batch time:  3.702e-02s
# [03:08:20] - [step:          0] record validators time:  1.579e+00s
# [03:08:20] - [step:          0] saved checkpoint to outputs/fhn2SIM/initial_conditions
# [03:08:20] - [step:          0] loss:  5.083e+02
# [03:08:21] - Attempting cuda graph building, this may take a bit...
# [03:08:23] - [step:        100] loss:  1.756e+01, time/iteration:  3.026e+01 ms
# [03:08:27] - [step:        200] loss:  5.283e+00, time/iteration:  4.037e+01 ms
# [03:08:33] - [step:        300] loss:  2.790e+00, time/iteration:  5.835e+01 ms
# [03:08:39] - [step:        400] loss:  8.392e-01, time/iteration:  5.815e+01 ms
# [03:08:45] - [step:        500] loss:  6.877e-01, time/iteration:  5.874e+01 ms
# [03:08:51] - [step:        600] loss:  2.378e-01, time/iteration:  5.859e+01 ms
# [03:08:57] - [step:        700] loss:  1.704e-01, time/iteration:  5.924e+01 ms
# [03:09:03] - [step:        800] loss:  2.119e-01, time/iteration:  5.885e+01 ms
# [03:09:09] - [step:        900] loss:  2.766e-01, time/iteration:  5.906e+01 ms
# [03:09:16] - [step:       1000] record validators time:  1.436e+00s
# [03:09:16] - [step:       1000] saved checkpoint to outputs/fhn2SIM/initial_conditions
# [03:09:16] - [step:       1000] loss:  4.005e-01, time/iteration:  7.808e+01 ms
# [03:09:22] - [step:       1100] loss:  8.045e-02, time/iteration:  6.024e+01 ms
# [03:09:28] - [step:       1200] loss:  4.218e-02, time/iteration:  5.983e+01 ms
# [03:09:34] - [step:       1300] loss:  5.252e-02, time/iteration:  6.074e+01 ms
# [03:09:40] - [step:       1400] loss:  2.510e-02, time/iteration:  6.027e+01 ms
# [03:09:47] - [step:       1500] loss:  6.633e-02, time/iteration:  6.075e+01 ms
# [03:09:53] - [step:       1600] loss:  2.592e-02, time/iteration:  6.045e+01 ms
# [03:09:59] - [step:       1700] loss:  3.890e-02, time/iteration:  6.131e+01 ms
# [03:10:05] - [step:       1800] loss:  3.532e-02, time/iteration:  6.096e+01 ms
# [03:10:11] - [step:       1900] loss:  1.565e-02, time/iteration:  6.172e+01 ms
# [03:10:18] - [step:       2000] record constraint batch time:  1.284e-01s
# [03:10:19] - [step:       2000] record validators time:  1.395e+00s
# [03:10:19] - [step:       2000] saved checkpoint to outputs/fhn2SIM/initial_conditions
# [03:10:19] - [step:       2000] loss:  1.400e-02, time/iteration:  8.097e+01 ms
# [03:10:19] - [step:       2000] reached maximum training steps, finished training!
# [03:10:19] - Solving for Domain window1, iteration 0
# [03:10:19] - attempting to restore from: outputs/fhn2SIM/window1
# [03:10:19] - optimizer checkpoint not found
# [03:10:19] - model network.0.pth not found
# [03:10:19] - [step:          0] record constraint batch time:  9.470e-02s
# [03:10:21] - [step:          0] record validators time:  1.448e+00s
# [03:10:21] - [step:          0] saved checkpoint to outputs/fhn2SIM/window1
# [03:10:21] - [step:          0] loss:  8.396e+00
# [03:10:22] - Attempting cuda graph building, this may take a bit...
# [03:10:27] - [step:        100] loss:  7.276e+00, time/iteration:  6.535e+01 ms
# [03:10:34] - [step:        200] loss:  1.155e+00, time/iteration:  6.886e+01 ms
# [03:10:41] - [step:        300] loss:  4.699e-01, time/iteration:  6.878e+01 ms
# [03:10:48] - [step:        400] loss:  2.870e-01, time/iteration:  6.852e+01 ms
# [03:10:55] - [step:        500] loss:  1.989e-01, time/iteration:  6.825e+01 ms
# [03:11:02] - [step:        600] loss:  1.533e-01, time/iteration:  6.832e+01 ms
# [03:11:09] - [step:        700] loss:  1.528e-01, time/iteration:  6.818e+01 ms
# [03:11:15] - [step:        800] loss:  8.868e-02, time/iteration:  6.803e+01 ms
# [03:11:22] - [step:        900] loss:  1.430e-01, time/iteration:  6.794e+01 ms
# [03:11:31] - [step:       1000] record validators time:  1.408e+00s
# [03:11:31] - [step:       1000] saved checkpoint to outputs/fhn2SIM/window1
# [03:11:31] - [step:       1000] loss:  9.169e-02, time/iteration:  8.566e+01 ms
# [03:11:37] - [step:       1100] loss:  7.126e-02, time/iteration:  6.781e+01 ms
# [03:11:44] - [step:       1200] loss:  1.499e-01, time/iteration:  6.782e+01 ms
# [03:11:51] - [step:       1300] loss:  1.075e-01, time/iteration:  6.810e+01 ms
# [03:11:58] - [step:       1400] loss:  3.443e-02, time/iteration:  6.795e+01 ms
# [03:12:05] - [step:       1500] loss:  4.447e-02, time/iteration:  6.827e+01 ms
# [03:12:12] - [step:       1600] loss:  3.589e-02, time/iteration:  6.861e+01 ms
# [03:12:18] - [step:       1700] loss:  4.866e-02, time/iteration:  6.870e+01 ms
# [03:12:25] - [step:       1800] loss:  1.214e-01, time/iteration:  6.869e+01 ms
# [03:12:32] - [step:       1900] loss:  4.545e-02, time/iteration:  6.876e+01 ms
# [03:12:39] - [step:       2000] record constraint batch time:  1.085e-01s
# [03:12:40] - [step:       2000] record validators time:  1.369e+00s
# [03:12:40] - [step:       2000] saved checkpoint to outputs/fhn2SIM/window1
# [03:12:40] - [step:       2000] loss:  3.092e-01, time/iteration:  8.183e+01 ms
# [03:12:40] - [step:       2000] reached maximum training steps, finished training!
# [03:12:40] - Solving for Domain window2, iteration 0
# [03:12:40] - attempting to restore from: outputs/fhn2SIM/window2
# [03:12:40] - optimizer checkpoint not found
# [03:12:40] - model network.0.pth not found
# [03:12:41] - [step:          0] record constraint batch time:  9.259e-02s
# [03:12:42] - [step:          0] record validators time:  1.398e+00s
# [03:12:42] - [step:          0] saved checkpoint to outputs/fhn2SIM/window2
# [03:12:42] - [step:          0] loss:  4.592e+03
# [03:12:44] - Attempting cuda graph building, this may take a bit...
# [03:12:49] - [step:        100] loss:  1.729e+01, time/iteration:  7.315e+01 ms
# [03:12:56] - [step:        200] loss:  6.872e+00, time/iteration:  6.833e+01 ms
# [03:13:03] - [step:        300] loss:  4.341e+00, time/iteration:  6.850e+01 ms
# [03:13:10] - [step:        400] loss:  7.526e-01, time/iteration:  6.850e+01 ms
# [03:13:17] - [step:        500] loss:  4.272e-01, time/iteration:  6.827e+01 ms
# [03:13:24] - [step:        600] loss:  1.840e-01, time/iteration:  6.847e+01 ms
# [03:13:30] - [step:        700] loss:  1.832e-01, time/iteration:  6.860e+01 ms
# [03:13:37] - [step:        800] loss:  4.443e-01, time/iteration:  6.838e+01 ms
# [03:13:44] - [step:        900] loss:  1.142e-01, time/iteration:  6.863e+01 ms
# [03:13:53] - [step:       1000] record validators time:  1.425e+00s
# [03:13:53] - [step:       1000] saved checkpoint to outputs/fhn2SIM/window2
# [03:13:53] - [step:       1000] loss:  2.242e+00, time/iteration:  8.582e+01 ms
# [03:14:00] - [step:       1100] loss:  1.035e-01, time/iteration:  6.810e+01 ms
# [03:14:06] - [step:       1200] loss:  1.110e-01, time/iteration:  6.847e+01 ms
# [03:14:13] - [step:       1300] loss:  2.017e+00, time/iteration:  6.826e+01 ms
# [03:14:20] - [step:       1400] loss:  1.167e-01, time/iteration:  6.846e+01 ms
# [03:14:27] - [step:       1500] loss:  7.120e-02, time/iteration:  6.858e+01 ms
# [03:14:34] - [step:       1600] loss:  1.354e-01, time/iteration:  6.832e+01 ms
# [03:14:41] - [step:       1700] loss:  2.276e-01, time/iteration:  6.840e+01 ms
# [03:14:47] - [step:       1800] loss:  3.386e-01, time/iteration:  6.825e+01 ms
# [03:14:53] - [step:       1900] loss:  6.933e-02, time/iteration:  5.523e+01 ms
# [03:14:59] - [step:       2000] record constraint batch time:  1.286e-01s
# [03:15:01] - [step:       2000] record validators time:  1.397e+00s
# [03:15:01] - [step:       2000] saved checkpoint to outputs/fhn2SIM/window2
# [03:15:01] - [step:       2000] loss:  7.257e-02, time/iteration:  7.837e+01 ms
# [03:15:01] - [step:       2000] reached maximum training steps, finished training!
# [03:15:01] - Solving for Domain window3, iteration 0
# [03:15:01] - attempting to restore from: outputs/fhn2SIM/window3
# [03:15:01] - optimizer checkpoint not found
# [03:15:01] - model network.0.pth not found
# [03:15:01] - [step:          0] record constraint batch time:  9.269e-02s
# [03:15:03] - [step:          0] record validators time:  1.442e+00s
# [03:15:03] - [step:          0] saved checkpoint to outputs/fhn2SIM/window3
# [03:15:03] - [step:          0] loss:  6.723e-01
# [03:15:04] - Attempting cuda graph building, this may take a bit...
# [03:15:10] - [step:        100] loss:  1.670e+00, time/iteration:  7.407e+01 ms
# [03:15:17] - [step:        200] loss:  1.074e+00, time/iteration:  6.889e+01 ms
# [03:15:24] - [step:        300] loss:  7.808e-01, time/iteration:  6.899e+01 ms
# [03:15:31] - [step:        400] loss:  6.139e-01, time/iteration:  6.909e+01 ms
# [03:15:38] - [step:        500] loss:  5.349e-01, time/iteration:  6.877e+01 ms
# [03:15:45] - [step:        600] loss:  4.835e-01, time/iteration:  6.898e+01 ms
# [03:15:51] - [step:        700] loss:  4.064e-01, time/iteration:  6.898e+01 ms
# [03:15:58] - [step:        800] loss:  3.575e-01, time/iteration:  6.903e+01 ms
# [03:16:05] - [step:        900] loss:  2.721e-01, time/iteration:  6.909e+01 ms
# [03:16:14] - [step:       1000] record validators time:  1.412e+00s
# [03:16:14] - [step:       1000] saved checkpoint to outputs/fhn2SIM/window3
# [03:16:14] - [step:       1000] loss:  2.106e-01, time/iteration:  8.639e+01 ms
# [03:16:21] - [step:       1100] loss:  1.782e-01, time/iteration:  6.909e+01 ms
# [03:16:28] - [step:       1200] loss:  1.571e-01, time/iteration:  6.905e+01 ms
# [03:16:35] - [step:       1300] loss:  1.576e-01, time/iteration:  6.913e+01 ms
# [03:16:42] - [step:       1400] loss:  1.082e-01, time/iteration:  6.907e+01 ms
# [03:16:48] - [step:       1500] loss:  5.167e-01, time/iteration:  6.908e+01 ms
# [03:16:55] - [step:       1600] loss:  7.289e-02, time/iteration:  6.905e+01 ms
# [03:17:02] - [step:       1700] loss:  7.414e-02, time/iteration:  6.911e+01 ms
# [03:17:08] - [step:       1800] loss:  3.746e-02, time/iteration:  5.802e+01 ms
# [03:17:15] - [step:       1900] loss:  5.516e-02, time/iteration:  6.843e+01 ms
# [03:17:22] - [step:       2000] record constraint batch time:  1.097e-01s
# [03:17:24] - [step:       2000] record validators time:  1.418e+00s
# [03:17:24] - [step:       2000] saved checkpoint to outputs/fhn2SIM/window3
# [03:17:24] - [step:       2000] loss:  2.399e-02, time/iteration:  8.787e+01 ms
# [03:17:24] - [step:       2000] reached maximum training steps, finished training!
# [03:17:24] - Solving for Domain window4, iteration 0
# [03:17:24] - attempting to restore from: outputs/fhn2SIM/window4
# [03:17:24] - optimizer checkpoint not found
# [03:17:24] - model network.0.pth not found
# [03:17:24] - [step:          0] record constraint batch time:  8.851e-02s
# [03:17:25] - [step:          0] record validators time:  1.439e+00s
# [03:17:26] - [step:          0] saved checkpoint to outputs/fhn2SIM/window4
# [03:17:26] - [step:          0] loss:  1.897e-01
# [03:17:27] - Attempting cuda graph building, this may take a bit...
# [03:17:33] - [step:        100] loss:  6.806e-01, time/iteration:  7.424e+01 ms
# [03:17:40] - [step:        200] loss:  3.761e-01, time/iteration:  6.897e+01 ms
# [03:17:47] - [step:        300] loss:  2.722e-01, time/iteration:  6.910e+01 ms
# [03:17:54] - [step:        400] loss:  2.133e-01, time/iteration:  6.897e+01 ms
# [03:18:01] - [step:        500] loss:  1.521e-01, time/iteration:  6.906e+01 ms
# [03:18:07] - [step:        600] loss:  1.160e-01, time/iteration:  6.896e+01 ms
# [03:18:14] - [step:        700] loss:  7.328e-02, time/iteration:  6.898e+01 ms
# [03:18:21] - [step:        800] loss:  6.292e-02, time/iteration:  6.904e+01 ms
# [03:18:28] - [step:        900] loss:  4.179e-02, time/iteration:  6.913e+01 ms
# [03:18:37] - [step:       1000] record validators time:  1.403e+00s
# [03:18:37] - [step:       1000] saved checkpoint to outputs/fhn2SIM/window4
# [03:18:37] - [step:       1000] loss:  2.707e-02, time/iteration:  8.631e+01 ms
# [03:18:44] - [step:       1100] loss:  7.224e-02, time/iteration:  6.917e+01 ms
# [03:18:51] - [step:       1200] loss:  1.648e-02, time/iteration:  6.912e+01 ms
# [03:18:58] - [step:       1300] loss:  2.819e-02, time/iteration:  6.907e+01 ms
# [03:19:04] - [step:       1400] loss:  1.489e-02, time/iteration:  6.903e+01 ms
# [03:19:11] - [step:       1500] loss:  1.074e-02, time/iteration:  6.920e+01 ms
# [03:19:18] - [step:       1600] loss:  1.150e-02, time/iteration:  6.896e+01 ms
# [03:19:24] - [step:       1700] loss:  2.733e-02, time/iteration:  5.721e+01 ms
# [03:19:31] - [step:       1800] loss:  1.159e-02, time/iteration:  6.881e+01 ms
# [03:19:38] - [step:       1900] loss:  6.030e-03, time/iteration:  6.901e+01 ms
# [03:19:45] - [step:       2000] record constraint batch time:  1.135e-01s
# [03:19:46] - [step:       2000] record validators time:  1.400e+00s
# [03:19:47] - [step:       2000] saved checkpoint to outputs/fhn2SIM/window4
# [03:19:47] - [step:       2000] loss:  6.715e-03, time/iteration:  8.760e+01 ms
# [03:19:47] - [step:       2000] reached maximum training steps, finished training!
# [03:19:47] - Solving for Domain window5, iteration 0
# [03:19:47] - attempting to restore from: outputs/fhn2SIM/window5
# [03:19:47] - optimizer checkpoint not found
# [03:19:47] - model network.0.pth not found
# [03:19:47] - [step:          0] record constraint batch time:  9.321e-02s
# [03:19:48] - [step:          0] record validators time:  1.411e+00s
# [03:19:48] - [step:          0] saved checkpoint to outputs/fhn2SIM/window5
# [03:19:48] - [step:          0] loss:  1.396e-02
# [03:19:50] - Attempting cuda graph building, this may take a bit...
# [03:19:56] - [step:        100] loss:  1.564e-01, time/iteration:  7.486e+01 ms
# [03:20:03] - [step:        200] loss:  8.649e-02, time/iteration:  6.891e+01 ms
# [03:20:10] - [step:        300] loss:  3.850e-02, time/iteration:  6.912e+01 ms
# [03:20:16] - [step:        400] loss:  2.109e-02, time/iteration:  6.883e+01 ms
# [03:20:23] - [step:        500] loss:  1.737e-02, time/iteration:  6.887e+01 ms
# [03:20:30] - [step:        600] loss:  1.087e-02, time/iteration:  6.918e+01 ms
# [03:20:37] - [step:        700] loss:  8.634e-03, time/iteration:  6.872e+01 ms
# [03:20:44] - [step:        800] loss:  6.836e-03, time/iteration:  6.886e+01 ms
# [03:20:51] - [step:        900] loss:  5.966e-03, time/iteration:  6.886e+01 ms
# [03:20:59] - [step:       1000] record validators time:  1.375e+00s
# [03:21:00] - [step:       1000] saved checkpoint to outputs/fhn2SIM/window5
# [03:21:00] - [step:       1000] loss:  8.177e-03, time/iteration:  8.583e+01 ms
# [03:21:06] - [step:       1100] loss:  8.438e-03, time/iteration:  6.864e+01 ms
# [03:21:13] - [step:       1200] loss:  3.934e-03, time/iteration:  6.911e+01 ms
# [03:21:20] - [step:       1300] loss:  2.441e-03, time/iteration:  6.893e+01 ms
# [03:21:27] - [step:       1400] loss:  3.450e-03, time/iteration:  6.908e+01 ms
# [03:21:34] - [step:       1500] loss:  3.609e-03, time/iteration:  6.890e+01 ms
# [03:21:39] - [step:       1600] loss:  3.737e-03, time/iteration:  5.073e+01 ms
# [03:21:45] - [step:       1700] loss:  1.592e-03, time/iteration:  6.355e+01 ms
# [03:21:52] - [step:       1800] loss:  1.540e-03, time/iteration:  6.903e+01 ms
# [03:21:59] - [step:       1900] loss:  1.139e-03, time/iteration:  6.880e+01 ms
# [03:22:06] - [step:       2000] record constraint batch time:  1.129e-01s
# [03:22:08] - [step:       2000] record validators time:  1.367e+00s
# [03:22:08] - [step:       2000] saved checkpoint to outputs/fhn2SIM/window5
# [03:22:08] - [step:       2000] loss:  2.796e-03, time/iteration:  8.697e+01 ms
# [03:22:08] - [step:       2000] reached maximum training steps, finished training!
# [03:22:08] - Solving for Domain window6, iteration 0
# [03:22:08] - attempting to restore from: outputs/fhn2SIM/window6
# [03:22:08] - optimizer checkpoint not found
# [03:22:08] - model network.0.pth not found
# [03:22:08] - [step:          0] record constraint batch time:  1.043e-01s
# [03:22:10] - [step:          0] record validators time:  1.460e+00s
# [03:22:10] - [step:          0] saved checkpoint to outputs/fhn2SIM/window6
# [03:22:10] - [step:          0] loss:  1.881e-02
# [03:22:11] - Attempting cuda graph building, this may take a bit...
# [03:22:17] - [step:        100] loss:  6.468e-02, time/iteration:  7.519e+01 ms
# [03:22:24] - [step:        200] loss:  3.072e-02, time/iteration:  6.894e+01 ms
# [03:22:31] - [step:        300] loss:  2.166e-02, time/iteration:  6.906e+01 ms
# [03:22:38] - [step:        400] loss:  2.246e-02, time/iteration:  6.920e+01 ms
# [03:22:45] - [step:        500] loss:  1.557e-02, time/iteration:  6.900e+01 ms
# [03:22:52] - [step:        600] loss:  1.397e-02, time/iteration:  6.907e+01 ms
# [03:22:59] - [step:        700] loss:  1.256e-02, time/iteration:  6.914e+01 ms
# [03:23:06] - [step:        800] loss:  7.807e-03, time/iteration:  6.900e+01 ms
# [03:23:13] - [step:        900] loss:  7.657e-03, time/iteration:  6.917e+01 ms
# [03:23:21] - [step:       1000] record validators time:  1.366e+00s
# [03:23:21] - [step:       1000] saved checkpoint to outputs/fhn2SIM/window6
# [03:23:21] - [step:       1000] loss:  6.637e-03, time/iteration:  8.679e+01 ms
# [03:23:28] - [step:       1100] loss:  5.724e-03, time/iteration:  6.906e+01 ms
# [03:23:35] - [step:       1200] loss:  4.850e-03, time/iteration:  6.894e+01 ms
# [03:23:42] - [step:       1300] loss:  4.532e-03, time/iteration:  6.897e+01 ms
# [03:23:49] - [step:       1400] loss:  3.655e-03, time/iteration:  6.895e+01 ms
# [03:23:55] - [step:       1500] loss:  2.820e-03, time/iteration:  5.765e+01 ms
# [03:24:01] - [step:       1600] loss:  4.227e-03, time/iteration:  6.907e+01 ms
# [03:24:08] - [step:       1700] loss:  2.277e-03, time/iteration:  6.907e+01 ms
# [03:24:15] - [step:       1800] loss:  4.579e-03, time/iteration:  6.907e+01 ms
# [03:24:22] - [step:       1900] loss:  6.657e-03, time/iteration:  6.897e+01 ms
# [03:24:30] - [step:       2000] record constraint batch time:  1.115e-01s
# [03:24:31] - [step:       2000] record validators time:  1.407e+00s
# [03:24:31] - [step:       2000] saved checkpoint to outputs/fhn2SIM/window6
# [03:24:31] - [step:       2000] loss:  8.539e-03, time/iteration:  8.768e+01 ms
# [03:24:31] - [step:       2000] reached maximum training steps, finished training!
# [03:24:31] - Solving for Domain window7, iteration 0
# [03:24:31] - attempting to restore from: outputs/fhn2SIM/window7
# [03:24:31] - optimizer checkpoint not found
# [03:24:31] - model network.0.pth not found
# [03:24:31] - [step:          0] record constraint batch time:  9.242e-02s
# [03:24:33] - [step:          0] record validators time:  1.440e+00s
# [03:24:33] - [step:          0] saved checkpoint to outputs/fhn2SIM/window7
# [03:24:33] - [step:          0] loss:  2.505e-02
# [03:24:34] - Attempting cuda graph building, this may take a bit...
# [03:24:40] - [step:        100] loss:  3.154e-02, time/iteration:  7.436e+01 ms
# [03:24:47] - [step:        200] loss:  2.899e-02, time/iteration:  6.897e+01 ms
# [03:24:54] - [step:        300] loss:  5.989e-02, time/iteration:  6.934e+01 ms
# [03:25:01] - [step:        400] loss:  2.958e-02, time/iteration:  6.911e+01 ms
# [03:25:08] - [step:        500] loss:  2.495e-02, time/iteration:  6.904e+01 ms
# [03:25:15] - [step:        600] loss:  2.395e-02, time/iteration:  6.907e+01 ms
# [03:25:22] - [step:        700] loss:  1.912e-02, time/iteration:  6.902e+01 ms
# [03:25:29] - [step:        800] loss:  1.756e-02, time/iteration:  6.902e+01 ms
# [03:25:36] - [step:        900] loss:  1.390e-02, time/iteration:  6.906e+01 ms
# [03:25:44] - [step:       1000] record validators time:  1.431e+00s
# [03:25:44] - [step:       1000] saved checkpoint to outputs/fhn2SIM/window7
# [03:25:44] - [step:       1000] loss:  1.538e-01, time/iteration:  8.697e+01 ms
# [03:25:51] - [step:       1100] loss:  1.056e-02, time/iteration:  6.901e+01 ms
# [03:25:58] - [step:       1200] loss:  1.013e-02, time/iteration:  6.902e+01 ms
# [03:26:04] - [step:       1300] loss:  1.035e-02, time/iteration:  6.161e+01 ms
# [03:26:11] - [step:       1400] loss:  2.113e-02, time/iteration:  6.455e+01 ms
# [03:26:18] - [step:       1500] loss:  8.849e-03, time/iteration:  6.909e+01 ms
# [03:26:24] - [step:       1600] loss:  6.910e-03, time/iteration:  6.891e+01 ms
# [03:26:31] - [step:       1700] loss:  6.463e-03, time/iteration:  6.898e+01 ms
# [03:26:38] - [step:       1800] loss:  5.095e-03, time/iteration:  6.905e+01 ms
# [03:26:45] - [step:       1900] loss:  4.160e-03, time/iteration:  6.895e+01 ms
# [03:26:52] - [step:       2000] record constraint batch time:  1.295e-01s
# [03:26:54] - [step:       2000] record validators time:  1.378e+00s
# [03:26:54] - [step:       2000] saved checkpoint to outputs/fhn2SIM/window7
# [03:26:54] - [step:       2000] loss:  9.499e-03, time/iteration:  8.738e+01 ms
# [03:26:54] - [step:       2000] reached maximum training steps, finished training!
# [03:26:54] - Solving for Domain window8, iteration 0
# [03:26:54] - attempting to restore from: outputs/fhn2SIM/window8
# [03:26:54] - optimizer checkpoint not found
# [03:26:54] - model network.0.pth not found
# [03:26:54] - [step:          0] record constraint batch time:  9.204e-02s
# [03:26:56] - [step:          0] record validators time:  1.412e+00s
# [03:26:56] - [step:          0] saved checkpoint to outputs/fhn2SIM/window8
# [03:26:56] - [step:          0] loss:  8.187e-03
# [03:26:57] - Attempting cuda graph building, this may take a bit...
# [03:27:03] - [step:        100] loss:  1.606e-02, time/iteration:  7.547e+01 ms
# [03:27:10] - [step:        200] loss:  1.139e-02, time/iteration:  6.915e+01 ms
# [03:27:17] - [step:        300] loss:  1.019e-02, time/iteration:  6.916e+01 ms
# [03:27:24] - [step:        400] loss:  8.475e-03, time/iteration:  6.913e+01 ms
# [03:27:31] - [step:        500] loss:  7.347e-03, time/iteration:  6.902e+01 ms
# [03:27:38] - [step:        600] loss:  6.420e-03, time/iteration:  6.913e+01 ms
# [03:27:45] - [step:        700] loss:  4.766e-03, time/iteration:  6.917e+01 ms
# [03:27:52] - [step:        800] loss:  3.483e-03, time/iteration:  6.913e+01 ms
# [03:27:59] - [step:        900] loss:  1.652e-02, time/iteration:  6.914e+01 ms
# [03:28:07] - [step:       1000] record validators time:  1.399e+00s
# [03:28:07] - [step:       1000] saved checkpoint to outputs/fhn2SIM/window8
# [03:28:07] - [step:       1000] loss:  2.712e-03, time/iteration:  8.660e+01 ms
# [03:28:14] - [step:       1100] loss:  3.159e-03, time/iteration:  6.847e+01 ms
# [03:28:19] - [step:       1200] loss:  2.339e-03, time/iteration:  5.413e+01 ms
# [03:28:25] - [step:       1300] loss:  3.672e-03, time/iteration:  5.936e+01 ms
# [03:28:32] - [step:       1400] loss:  1.932e-03, time/iteration:  6.900e+01 ms
# [03:28:39] - [step:       1500] loss:  2.138e-03, time/iteration:  6.910e+01 ms
# [03:28:46] - [step:       1600] loss:  1.724e-03, time/iteration:  6.907e+01 ms
# [03:28:53] - [step:       1700] loss:  1.541e-03, time/iteration:  6.900e+01 ms
# [03:29:00] - [step:       1800] loss:  1.776e-03, time/iteration:  6.909e+01 ms
# [03:29:07] - [step:       1900] loss:  2.618e-03, time/iteration:  6.911e+01 ms
# [03:29:14] - [step:       2000] record constraint batch time:  1.124e-01s
# [03:29:16] - [step:       2000] record validators time:  1.386e+00s
# [03:29:16] - [step:       2000] saved checkpoint to outputs/fhn2SIM/window8
# [03:29:16] - [step:       2000] loss:  1.459e-03, time/iteration:  8.756e+01 ms
# [03:29:16] - [step:       2000] reached maximum training steps, finished training!
# [03:29:16] - Solving for Domain window9, iteration 0
# [03:29:16] - attempting to restore from: outputs/fhn2SIM/window9
# [03:29:16] - optimizer checkpoint not found
# [03:29:16] - model network.0.pth not found
# [03:29:16] - [step:          0] record constraint batch time:  9.165e-02s
# [03:29:17] - [step:          0] record validators time:  1.410e+00s
# [03:29:17] - [step:          0] saved checkpoint to outputs/fhn2SIM/window9
# [03:29:17] - [step:          0] loss:  3.950e-03
# [03:29:19] - Attempting cuda graph building, this may take a bit...
# [03:29:25] - [step:        100] loss:  4.350e-03, time/iteration:  7.525e+01 ms
# [03:29:32] - [step:        200] loss:  5.820e-02, time/iteration:  6.890e+01 ms
# [03:29:39] - [step:        300] loss:  2.980e-03, time/iteration:  6.900e+01 ms
# [03:29:46] - [step:        400] loss:  2.750e-03, time/iteration:  6.879e+01 ms
# [03:29:52] - [step:        500] loss:  2.507e-03, time/iteration:  6.887e+01 ms
# [03:29:59] - [step:        600] loss:  1.718e-01, time/iteration:  6.892e+01 ms
# [03:30:06] - [step:        700] loss:  2.042e-03, time/iteration:  6.893e+01 ms
# [03:30:13] - [step:        800] loss:  1.794e-03, time/iteration:  6.891e+01 ms
# [03:30:20] - [step:        900] loss:  2.634e-03, time/iteration:  6.890e+01 ms
# [03:30:29] - [step:       1000] record validators time:  1.413e+00s
# [03:30:29] - [step:       1000] saved checkpoint to outputs/fhn2SIM/window9
# [03:30:29] - [step:       1000] loss:  1.485e-03, time/iteration:  8.699e+01 ms
# [03:30:34] - [step:       1100] loss:  1.317e-03, time/iteration:  5.742e+01 ms
# [03:30:41] - [step:       1200] loss:  3.715e-03, time/iteration:  6.879e+01 ms
# [03:30:48] - [step:       1300] loss:  9.101e-04, time/iteration:  6.909e+01 ms
# [03:30:55] - [step:       1400] loss:  3.447e-01, time/iteration:  6.904e+01 ms
# [03:31:02] - [step:       1500] loss:  9.384e-04, time/iteration:  6.904e+01 ms
# [03:31:09] - [step:       1600] loss:  8.678e-04, time/iteration:  6.909e+01 ms
# [03:31:16] - [step:       1700] loss:  7.512e-04, time/iteration:  6.900e+01 ms
# [03:31:23] - [step:       1800] loss:  1.080e-03, time/iteration:  6.901e+01 ms
# [03:31:30] - [step:       1900] loss:  7.274e-04, time/iteration:  6.898e+01 ms
# [03:31:37] - [step:       2000] record constraint batch time:  1.289e-01s
# [03:31:38] - [step:       2000] record validators time:  1.369e+00s
# [03:31:38] - [step:       2000] saved checkpoint to outputs/fhn2SIM/window9
# [03:31:38] - [step:       2000] loss:  3.195e-02, time/iteration:  8.778e+01 ms
# [03:31:38] - [step:       2000] reached maximum training steps, finished training!
