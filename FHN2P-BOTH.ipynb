# %%
# %%writefile conf/config.yaml
# # Arch	                        Start Lr	Max Steps	Decay Steps
# # FullyConnectedArch	        1.00E-03	1500000	        15000
# # FourierNetArch                1.00E-03	400000	        7500
# # ModifiedFourierNetArch 	1.00E-03	400000	        7500
# # SirenArch                     2.00E-05	500000	        5000
# # DGMArch                       1.00E-03        1500000         15000
#
# # WARNING: Setting "exact_continuity" to true or setting the arch
# # as "ModifiedFourierNetArch" increases the memory requirements of the
# # problem. Batchsizes may need to be reduced for such cases.
#
# defaults :
#   - modulus_default
#   - arch:
#       - fully_connected
#   - scheduler: exponential_lr
#   - optimizer: adam
#   - loss: sum
#   - _self_
#
# jit: false
#
#
# training:
#   rec_results_freq : 1000
#   rec_constraint_freq: 1000
#   max_steps : 3000
#
# batch_size:
#   initial_condition: 4096
#   interior: 4096
# Out:
# Overwriting conf/config.yaml

# %%
# %%writefile fhn2eqtwboth.py
from modulus.models.fully_connected import FullyConnectedArch
from modulus.models.fourier_net import FourierNetArch
from modulus.models.siren import SirenArch
from modulus.models.modified_fourier_net import ModifiedFourierNetArch
from modulus.models.dgm import DGMArch

from sympy import Symbol, Eq
from sympy import Symbol, Function, Number
from modulus.eq.pde import PDE
import numpy as np
import matplotlib.pyplot as plt
from scipy import interpolate
import modulus
from modulus.hydra import instantiate_arch, ModulusConfig
from modulus.solver import Solver
from modulus.domain import Domain
from modulus.geometry.primitives_1d import Point1D
from modulus.domain.constraint import (
    PointwiseBoundaryConstraint,
    PointwiseInteriorConstraint,
)
from modulus.domain.validator import PointwiseValidator
from modulus.key import Key
from modulus.node import Node
from modulus.eq.pde import PDE
from modulus.geometry import Parameterization
from sympy import Symbol, Eq, Abs, tanh, Or, And
from modulus.utils.io import (
    csv_to_dict,
    ValidatorPlotter,
    InferencerPlotter,
)
from modulus.solver import SequentialSolver

from modulus.models.deeponet import DeepONetArch
from modulus.domain.constraint.continuous import DeepONetConstraint
from modulus.models.moving_time_window import MovingTimeWindowArch
from modulus.domain.monitor import Monitor
from modulus.domain.constraint import Constraint
from modulus.graph import Graph
from modulus.key import Key
from modulus.constants import TF_SUMMARY
from modulus.distributed import DistributedManager
from modulus.utils.io import dict_to_csv, csv_to_dict
from modulus.domain.inferencer.pointwise import PointwiseInferencer as PointwiseInferencer

class MONI(Monitor):
    """
    Pointwise Inferencer that allows inferencing on pointwise data

    Parameters
    ----------
    invar : Dict[str, np.ndarray (N, 1)]
        Dictionary of numpy arrays as input.
    output_names : List[str]
        List of outputs needed for metric.
    metrics : Dict[str, Callable]
        Dictionary of pytorch functions whose input is a dictionary
        torch tensors whose keys are the `output_names`. The keys
        to `metrics` will be used to label the metrics in tensorboard/csv outputs.
    nodes : List[Node]
        List of Modulus Nodes to unroll graph with.
    requires_grad : bool = False
        If automatic differentiation is needed for computing results.
    """

    def __init__(self, invar, output_names, metrics, nodes, requires_grad=False):

        # construct model from nodes
        self.requires_grad = requires_grad
        self.model = Graph(
            nodes, Key.convert_list(invar.keys()), Key.convert_list(output_names)
        )
        self.manager = DistributedManager()
        self.device = self.manager.device
        self.model.to(self.device)

        # set metrics
        self.metrics = metrics
        self.monitor_outvar_store = {}

        # set invar
        self.invar = Constraint._set_device(invar, device=self.device)

    def save_results(self, name, writer, step, data_dir):
        plt.clf()
        # run forward inference
        invar = Constraint._set_device(
            self.invar, device=self.device, requires_grad=self.requires_grad
        )
        outvar = self.model(invar)
        metrics = {key: func({**invar, **outvar}) for key, func in self.metrics.items()}
        t=metrics["t"].detach().cpu().numpy()
        x1=metrics["x1"].detach().cpu().numpy()
        odex1=metrics["ode_x1"].detach().cpu().numpy()
        plt.scatter(t,x1)
        
        plt.savefig(data_dir+"x1s"+str(step)+".png")
        plt.clf()
        plt.scatter(t,odex1)
       # print(t)

        
        plt.savefig(data_dir+"ode_x1s"+str(step)+".png")
       
        return metrics

    
t_max = 10.0
n_w=10
t_w= t_max/n_w
def generateExactSolution(t,dt,x0,w0,rate,P,begin,end):
    
    
    n2=int(t/(dt))+2
    n = int((end-begin)/(dt*rate))
    Sol=np.zeros((n,3))
  
    Sol2=np.zeros((n2,2))
    Sol2[0]=x0,w0
    T=0
    k=0
    while(k<n2-1):
        x,w=Sol2[k]
        Sol2[k+1]=10*(x*(x-0.4)*(1-x)-w)*dt+  x, 0.5*(x*0.2-0.8*w)*dt +w
 
        if ((k*dt==begin or ((k+1)%rate == 0 and k*dt>=begin and k*dt<=end))and T<n):
          
           
            Sol[T] = Sol2[k][0],Sol2[k][1] , k*dt
            T=T+1
        
        k=k+1
        if(k*dt > end):
            break
    return Sol

def generateValidator(w_i,nodes):

    
    
    T=np.empty([0])
    K=np.empty([0])
    SOLs=np.empty([0])
    SOLw=np.empty([0])
    V=np.empty([0])
    krange= [(0 + 0.049*i*1) for i in range(0,20)]
    vrange= [(0 + 0.049*i*1) for i in range(0,20)]

    deltaT = 0.01
    
    rate=20
    for KR in krange:
        for VR in vrange:
            begin=w_i* t_w
            end=begin + t_w
            sol=generateExactSolution(t_max,deltaT,KR,VR,rate,KR,begin,end)

            T=np.append(T,sol.T[2] - begin)
            K = np.append(K,np.full_like (sol.T[2],KR))
            V= np.append(V,np.full_like(sol.T[2],VR))
            SOLs=np.append(SOLs,sol.T[0])
            SOLw=np.append(SOLw,sol.T[1])
    
    
    t = np.expand_dims(T, axis=-1)


    k = np.expand_dims(K, axis=-1)

    
    Solx = np.expand_dims(SOLs, axis=-1)

    
    Solw = np.expand_dims(SOLw, axis=-1)
   
    v= np.expand_dims(V,axis=-1)
    print(t,"val set de ",begin,"a ", end)

    
    invar_numpy = {"t": t,"K":k,"V":v}
    outvar_numpy = {
        "x1": Solx,
        "w":Solw
    }
   
    validator = PointwiseValidator(
        nodes=nodes, invar=invar_numpy, true_outvar=outvar_numpy, batch_size=1024,plotter=None
    )
    return validator

def generateDataC(w_i,nodes):

    
    
    T=np.empty([0])
    K=np.empty([0])
    SOLs=np.empty([0])
    SOLw=np.empty([0])
    V=np.empty([0])
    krange= [(0.0+ 0.02*i*1) for i in range(0,50)]
    vrange= [(0.0+ 0.02*i*1) for i in range(0,50)]

    deltaT = 0.01
    
    rate=1
    for KR in krange:
        for VR in vrange:
            begin=w_i* t_w
            end=begin + t_w
            sol=generateExactSolution(t_max,deltaT,KR,VR,rate,KR,begin,end)

            T=np.append(T,sol.T[2] - begin)
            K = np.append(K,np.full_like (sol.T[2],KR))
            V= np.append(V,np.full_like(sol.T[2],VR))
            SOLs=np.append(SOLs,sol.T[0])
            SOLw=np.append(SOLw,sol.T[1])
    
    
    t = np.expand_dims(T, axis=-1)


    k = np.expand_dims(K, axis=-1)

    
    Solx = np.expand_dims(SOLs, axis=-1)

    
    Solw = np.expand_dims(SOLw, axis=-1)
   
    v= np.expand_dims(V,axis=-1)
    print(t,"val set de ",begin,"a ", end)

    
    invar_numpy = {"t": t,"K":k,"V":v}
    outvar_numpy = {
        "x1": Solx,
        "w":Solw
    }
    print(np.shape(Solx),np.shape(Solw),np.shape(t),np.shape(k),np.shape(v))
    data = DeepONetConstraint.from_numpy(
        nodes=nodes,
        invar=invar_numpy,
        outvar=outvar_numpy,
        batch_size=7000,
        lambda_weighting=None
    )
    return data



class SpringMass(PDE):
    name = "SpringMass"

    def __init__(self):

        t = Symbol("t")
       
        input_variables = {"t": t}

        x = Function("x1")(*input_variables)
        w= Function("w")(*input_variables)
        self.equations = {}
        self.equations["ode_x1"] =10*(x*(x-0.4)*(1-x)-w) -x.diff(t)
        self.equations["ode_w"]  =0.5*(x*0.2-0.8*w) -w.diff(t)
        
@modulus.main(config_path="conf", config_name="config")
def run(cfg: ModulusConfig) -> None:
    
    # make list of nodes to unroll graph on
    sm = SpringMass()
    sm.pprint()
    #sm_net = FullyConnectedArch(
    #    input_keys=[Key("t"), Key("K")],
    #    output_keys=[Key("x1")],
    #)
    #nodes = sm.make_nodes() + [
    #    sm_net.make_node(name="network")
    #]


    
    # make list of nodes to unroll graph on
    sm = SpringMass()
    sm.pprint()
    #sm_net = FullyConnectedArch(
    #    input_keys=[Key("t"), Key("K")],
    #    output_keys=[Key("x1")],
    #)
    #nodes = sm.make_nodes() + [
    #    sm_net.make_node(name="network")
    #]

    
    
    flow_net = FullyConnectedArch(
            input_keys=[Key("t"), Key("K"),Key("V") ],
            output_keys=[Key("x1"),Key("w")],
            layer_size=300,
            nr_layers=10,
        )

    

    time_window_net = MovingTimeWindowArch(flow_net, t_w)

    nodes = sm.make_nodes() +[time_window_net.make_node(name="network")]


    for node in nodes:
        print(node.__str__())
   
    # add constraints to solver
    # make geometry
    geo = Point1D(0)
    
    t_symbol = Symbol("t")
    x_symbol = Symbol("x1")
    k_symbol= Symbol("K")
    v_symbol= Symbol("V")

    time_range = {t_symbol: (0,t_w )}
    k_range= {k_symbol:(0,1)}
    v_range= {v_symbol:(0,1)}

    tr = {t_symbol: (0, t_w)}

    # make domain
        # make initial condition domain
    ic_domain = Domain("initial_conditions")

  
    # initial conditions
    IC = PointwiseBoundaryConstraint(
        nodes=nodes,
        geometry=geo,
        outvar={"x1": k_symbol,"w":v_symbol},
        batch_size=3000,
        parameterization={**{t_symbol:0},**k_range,**v_range},
        lambda_weighting={
            "x1": 10,# + 1000*x_symbol.diff(t_symbol)*x_symbol.diff(t_symbol),
            "w": 10 #+ 1000*x_symbol.diff(t_symbol)*x_symbol.diff(t_symbol)
        },
        
        
        quasirandom=True,
    )

    ic_domain.add_constraint(IC, name="IC")
    
        # solve over given time period
    interior = PointwiseBoundaryConstraint(
        nodes=nodes,
        geometry=geo,
        outvar={"ode_x1": 0.0,"ode_w":0.0},
        batch_size=3000,
        parameterization={**tr,**k_range,**v_range},
        #criteria=And(t_symbol > 0, t_symbol < 3),
        lambda_weighting={
            "ode_x1": 1,# + 1000*x_symbol.diff(t_symbol)*x_symbol.diff(t_symbol),
            "ode_w":1 #+ 1000*x_symbol.diff(t_symbol)*x_symbol.diff(t_symbol)
        },
        quasirandom=True,
    )
    ic_domain.add_constraint(interior, name="interior")
    
    
       # solve over given time period
    interior2 = PointwiseBoundaryConstraint(
        nodes=nodes,
        geometry=geo,
        outvar={"ode_x1": 0.0,"ode_w":0.0},
        batch_size=500,
        parameterization={**tr,**{k_symbol:(0.6,1)},**{v_symbol:(0.0,0.1)}},
        #criteria=And(t_symbol > 0, t_symbol < 3),
        lambda_weighting={
            "ode_x1":1,# + 1000*x_symbol.diff(t_symbol)*x_symbol.diff(t_symbol),
            "ode_w": 1 #+ 1000*x_symbol.diff(t_symbol)*x_symbol.diff(t_symbol)
        },
        quasirandom=True,
    )
    ic_domain.add_constraint(interior2, name="interiorTr")
    
    
    
    domains=[]
    for i in range(1,n_w):

        # make moving window domain
        window_domain = Domain("window"+str(i))

        # solve over given time period
        interior1 = PointwiseBoundaryConstraint(
        nodes=nodes,
        geometry=geo,
        outvar={"ode_x1": 0.0,"ode_w":0.0},
        batch_size=3000,
        parameterization={**tr,**k_range,**v_range},
        #criteria=And(t_symbol > 0, t_symbol < 3),
        lambda_weighting={
            "ode_x1": 1,# + 1000*x_symbol.diff(t_symbol)*x_symbol.diff(t_symbol),
            "ode_w": 1 #+ 1000*x_symbol.diff(t_symbol)*x_symbol.diff(t_symbol)
        },
        quasirandom=True,

        )
        interior2 = PointwiseBoundaryConstraint(
        nodes=nodes,
        geometry=geo,
        outvar={"ode_x1": 0.0,"ode_w":0.0},
        batch_size=3000,
        parameterization={**tr,**{v_symbol:(0.0,0.1)},**k_range},
        #criteria=And(t_symbol > 0, t_symbol < 3),
        lambda_weighting={
            "ode_x1": 1,# + 1000*x_symbol.diff(t_symbol)*x_symbol.diff(t_symbol),
            "ode_w":  1 #+ 1000*x_symbol.diff(t_symbol)*x_symbol.diff(t_symbol)
        },
        quasirandom=True,

        )
        
        
        IC = PointwiseBoundaryConstraint(
        nodes=nodes,
        geometry=geo,
        outvar={"x1_prev_step_diff":0,"w_prev_step_diff":0},
        batch_size=500,
        parameterization={**{t_symbol:0},**k_range,**v_range},
        lambda_weighting={
            "x1_prev_step_diff": 10,
            "w_prev_step_diff": 10
        },
        
        quasirandom=True,
    )
        
    
        
        window_domain.add_constraint(IC, name="IC")
        window_domain.add_constraint(interior1, "interior")
        window_domain.add_constraint(interior2, "interiorTr")

        domains.append(window_domain)
    

    
 
    
    

    
    dom=[]
    dom.append((1,ic_domain))

    for domain in domains:
        dom.append((1,domain))
    print(cfg)
    # make solver
    #slv = Solver(cfg, domain)
    #print(domains)
    i=0
    for a,d in dom:
        print(d)
        print(d.name)
        d.add_validator(generateValidator(i,nodes))
        d.add_constraint(generateDataC(i,nodes),"data")

        i=i+1
    
      
    slv = SequentialSolver(
        cfg,
        dom,
        custom_update_operation=time_window_net.move_window,


    )

    # start solver
    slv.solve()

        
        
        
if __name__ == "__main__":
    run()
# Out:
# Overwriting fhn2eqtwboth.py

# %%
# !rm -r outputs/fhn2eqtwboth || true ##se não limpar o output ele aproveita o treinamento, mesmo se mudar o modelo
# !python fhn2eqtwboth.py
# Out:
# [06:27:33] - JitManager: {'_enabled': False, '_arch_mode': <JitArchMode.ONLY_ACTIVATION: 1>, '_use_nvfuser': True, '_autograd_nodes': False}
# [06:27:33] - GraphManager: {'_func_arch': False, '_debug': False, '_func_arch_allow_partial_hessian': True}
# ode_x1: 10*(1 - x1)*(x1 - 0.4)*x1 - 10*w - x1__t
# ode_w: -0.4*w + 0.1*x1 - w__t
# ode_x1: 10*(1 - x1)*(x1 - 0.4)*x1 - 10*w - x1__t
# ode_w: -0.4*w + 0.1*x1 - w__t
# node: Sympy Node: ode_x1
# evaluate: SympyToTorch
# inputs: [w, x1]
# derivatives: [x1__t]
# outputs: [ode_x1]
# optimize: False
# node: Sympy Node: ode_w
# evaluate: SympyToTorch
# inputs: [w, x1]
# derivatives: [w__t]
# outputs: [ode_w]
# optimize: False
# node: Arch Node: network
# evaluate: MovingTimeWindowArch
# inputs: [t, K, V]
# derivatives: []
# outputs: [x1, w, x1_prev_step, w_prev_step, x1_prev_step_diff, w_prev_step_diff]
# optimize: True
# {'training': {'max_steps': 3000, 'grad_agg_freq': 1, 'rec_results_freq': 1000, 'rec_validation_freq': '${training.rec_results_freq}', 'rec_inference_freq': '${training.rec_results_freq}', 'rec_monitor_freq': '${training.rec_results_freq}', 'rec_constraint_freq': 1000, 'save_network_freq': 1000, 'print_stats_freq': 100, 'summary_freq': 1000, 'amp': False, 'amp_dtype': 'float16', 'ntk': {'use_ntk': False, 'save_name': None, 'run_freq': 1000}}, 'graph': {'func_arch': False, 'func_arch_allow_partial_hessian': True}, 'stop_criterion': {'metric': None, 'min_delta': None, 'patience': 50000, 'mode': 'min', 'freq': 1000, 'strict': False}, 'profiler': {'profile': False, 'start_step': 0, 'end_step': 100, 'name': 'nvtx'}, 'network_dir': '.', 'initialization_network_dir': '', 'save_filetypes': 'vtk', 'summary_histograms': False, 'jit': False, 'jit_use_nvfuser': True, 'jit_arch_mode': 'only_activation', 'jit_autograd_nodes': False, 'cuda_graphs': True, 'cuda_graph_warmup': 20, 'find_unused_parameters': False, 'broadcast_buffers': False, 'device': '', 'debug': False, 'run_mode': 'train', 'arch': {'fully_connected': {'arch_type': 'fully_connected', 'input_keys': '???', 'output_keys': '???', 'detach_keys': '???', 'scaling': None, 'layer_size': 512, 'nr_layers': 6, 'skip_connections': False, 'activation_fn': 'silu', 'adaptive_activations': False, 'weight_norm': True}}, 'models': '???', 'loss': {'_target_': 'modulus.loss.aggregator.Sum', 'weights': None}, 'optimizer': {'_params_': {'compute_gradients': 'adam_compute_gradients', 'apply_gradients': 'adam_apply_gradients'}, '_target_': 'torch.optim.Adam', 'lr': 0.001, 'betas': [0.9, 0.999], 'eps': 1e-08, 'weight_decay': 0.0, 'amsgrad': False}, 'scheduler': {'_target_': 'torch.optim.lr_scheduler.ExponentialLR', 'gamma': 0.99998718}, 'batch_size': {'initial_condition': 4096, 'interior': 4096}, 'custom': '???'}
# <modulus.domain.domain.Domain object at 0x7f2a905b32b0>
# initial_conditions
# [[0.  ]
#  [0.19]
#  [0.39]
#  ...
#  [0.39]
#  [0.59]
#  [0.79]] val set de  0.0 a  1.0
# [[0.  ]
#  [0.01]
#  [0.02]
#  ...
#  [0.97]
#  [0.98]
#  [0.99]] val set de  0.0 a  1.0
# (250000, 1) (250000, 1) (250000, 1) (250000, 1) (250000, 1)
# <modulus.domain.domain.Domain object at 0x7f2a90593fa0>
# window1
# [[0.  ]
#  [0.19]
#  [0.39]
#  ...
#  [0.39]
#  [0.59]
#  [0.79]] val set de  1.0 a  2.0
# [[0.  ]
#  [0.01]
#  [0.02]
#  ...
#  [0.97]
#  [0.98]
#  [0.99]] val set de  1.0 a  2.0
# (250000, 1) (250000, 1) (250000, 1) (250000, 1) (250000, 1)
# <modulus.domain.domain.Domain object at 0x7f2a905b3f70>
# window2
# [[0.  ]
#  [0.19]
#  [0.39]
#  ...
#  [0.39]
#  [0.59]
#  [0.79]] val set de  2.0 a  3.0
# [[0.  ]
#  [0.01]
#  [0.02]
#  ...
#  [0.97]
#  [0.98]
#  [0.99]] val set de  2.0 a  3.0
# (250000, 1) (250000, 1) (250000, 1) (250000, 1) (250000, 1)
# <modulus.domain.domain.Domain object at 0x7f2a9034cf40>
# window3
# [[0.  ]
#  [0.19]
#  [0.39]
#  ...
#  [0.39]
#  [0.59]
#  [0.79]] val set de  3.0 a  4.0
# [[0.  ]
#  [0.01]
#  [0.02]
#  ...
#  [0.97]
#  [0.98]
#  [0.99]] val set de  3.0 a  4.0
# (250000, 1) (250000, 1) (250000, 1) (250000, 1) (250000, 1)
# <modulus.domain.domain.Domain object at 0x7f2a9035cc10>
# window4
# [[0.  ]
#  [0.19]
#  [0.39]
#  ...
#  [0.39]
#  [0.59]
#  [0.79]] val set de  4.0 a  5.0
# [[0.  ]
#  [0.01]
#  [0.02]
#  ...
#  [0.97]
#  [0.98]
#  [0.99]] val set de  4.0 a  5.0
# (250000, 1) (250000, 1) (250000, 1) (250000, 1) (250000, 1)
# <modulus.domain.domain.Domain object at 0x7f2a9034f7f0>
# window5
# [[0.  ]
#  [0.19]
#  [0.39]
#  ...
#  [0.39]
#  [0.59]
#  [0.79]] val set de  5.0 a  6.0
# [[0.  ]
#  [0.01]
#  [0.02]
#  ...
#  [0.97]
#  [0.98]
#  [0.99]] val set de  5.0 a  6.0
# (250000, 1) (250000, 1) (250000, 1) (250000, 1) (250000, 1)
# <modulus.domain.domain.Domain object at 0x7f2a9036e8e0>
# window6
# [[0.  ]
#  [0.19]
#  [0.39]
#  ...
#  [0.39]
#  [0.59]
#  [0.79]] val set de  6.0 a  7.0
# [[0.  ]
#  [0.01]
#  [0.02]
#  ...
#  [0.97]
#  [0.98]
#  [0.99]] val set de  6.0 a  7.0
# (250000, 1) (250000, 1) (250000, 1) (250000, 1) (250000, 1)
# <modulus.domain.domain.Domain object at 0x7f2a9030af10>
# window7
# [[0.  ]
#  [0.19]
#  [0.39]
#  ...
#  [0.39]
#  [0.59]
#  [0.79]] val set de  7.0 a  8.0
# [[0.  ]
#  [0.01]
#  [0.02]
#  ...
#  [0.97]
#  [0.98]
#  [0.99]] val set de  7.0 a  8.0
# (250000, 1) (250000, 1) (250000, 1) (250000, 1) (250000, 1)
# <modulus.domain.domain.Domain object at 0x7f2a9031be80>
# window8
# [[0.  ]
#  [0.19]
#  [0.39]
#  ...
#  [0.39]
#  [0.59]
#  [0.79]] val set de  8.0 a  9.0
# [[0.  ]
#  [0.01]
#  [0.02]
#  ...
#  [0.97]
#  [0.98]
#  [0.99]] val set de  8.0 a  9.0
# (250000, 1) (250000, 1) (250000, 1) (250000, 1) (250000, 1)
# <modulus.domain.domain.Domain object at 0x7f2a96a68cd0>
# window9
# [[0.  ]
#  [0.19]
#  [0.39]
#  ...
#  [0.39]
#  [0.59]
#  [0.79]] val set de  9.0 a  10.0
# [[0.  ]
#  [0.01]
#  [0.02]
#  ...
#  [0.97]
#  [0.98]
#  [0.99]] val set de  9.0 a  10.0
# (250000, 1) (250000, 1) (250000, 1) (250000, 1) (250000, 1)
# [06:28:52] - Solving for Domain initial_conditions, iteration 0
# [06:28:52] - attempting to restore from: outputs/fhn2eqtwboth/initial_conditions
# [06:28:52] - optimizer checkpoint not found
# [06:28:52] - model network.0.pth not found
# [06:28:54] - [step:          0] record constraint batch time:  1.058e-01s
# [06:28:54] - [step:          0] record validators time:  1.224e-02s
# [06:28:54] - [step:          0] saved checkpoint to outputs/fhn2eqtwboth/initial_conditions
# [06:28:54] - [step:          0] loss:  2.674e+03
# [06:28:55] - Attempting cuda graph building, this may take a bit...
# [06:29:01] - [step:        100] loss:  5.266e+01, time/iteration:  7.779e+01 ms
# [06:29:09] - [step:        200] loss:  9.221e+00, time/iteration:  7.559e+01 ms
# [06:29:16] - [step:        300] loss:  4.546e+00, time/iteration:  7.570e+01 ms
# [06:29:24] - [step:        400] loss:  3.675e+00, time/iteration:  7.600e+01 ms
# [06:29:32] - [step:        500] loss:  1.949e+00, time/iteration:  7.627e+01 ms
# [06:29:39] - [step:        600] loss:  1.338e+00, time/iteration:  7.648e+01 ms
# [06:29:47] - [step:        700] loss:  1.602e+00, time/iteration:  7.656e+01 ms
# [06:29:55] - [step:        800] loss:  3.761e+00, time/iteration:  7.656e+01 ms
# [06:30:02] - [step:        900] loss:  4.891e-01, time/iteration:  7.713e+01 ms
# [06:30:11] - [step:       1000] record constraint batch time:  1.485e-01s
# [06:30:11] - [step:       1000] record validators time:  1.146e-02s
# [06:30:11] - [step:       1000] saved checkpoint to outputs/fhn2eqtwboth/initial_conditions
# [06:30:11] - [step:       1000] loss:  4.359e-01, time/iteration:  8.876e+01 ms
# [06:30:19] - [step:       1100] loss:  2.236e+00, time/iteration:  7.802e+01 ms
# [06:30:27] - [step:       1200] loss:  5.313e-01, time/iteration:  7.800e+01 ms
# [06:30:35] - [step:       1300] loss:  4.689e-01, time/iteration:  7.820e+01 ms
# [06:30:43] - [step:       1400] loss:  6.394e-01, time/iteration:  7.852e+01 ms
# [06:30:50] - [step:       1500] loss:  2.279e+00, time/iteration:  7.832e+01 ms
# [06:30:58] - [step:       1600] loss:  7.564e-01, time/iteration:  7.876e+01 ms
# [06:31:06] - [step:       1700] loss:  2.125e-01, time/iteration:  7.916e+01 ms
# [06:31:14] - [step:       1800] loss:  4.905e-01, time/iteration:  7.955e+01 ms
# [06:31:22] - [step:       1900] loss:  1.717e+00, time/iteration:  7.960e+01 ms
# [06:31:31] - [step:       2000] record constraint batch time:  8.895e-02s
# [06:31:31] - [step:       2000] record validators time:  1.202e-02s
# [06:31:31] - [step:       2000] saved checkpoint to outputs/fhn2eqtwboth/initial_conditions
# [06:31:31] - [step:       2000] loss:  1.329e+00, time/iteration:  9.078e+01 ms
# [06:31:39] - [step:       2100] loss:  1.385e+00, time/iteration:  7.993e+01 ms
# [06:31:47] - [step:       2200] loss:  1.561e-01, time/iteration:  7.929e+01 ms
# [06:31:55] - [step:       2300] loss:  4.117e+00, time/iteration:  7.948e+01 ms
# [06:32:03] - [step:       2400] loss:  1.181e-01, time/iteration:  7.934e+01 ms
# [06:32:11] - [step:       2500] loss:  3.032e-01, time/iteration:  7.953e+01 ms
# [06:32:19] - [step:       2600] loss:  3.896e-01, time/iteration:  7.925e+01 ms
# [06:32:27] - [step:       2700] loss:  2.017e-01, time/iteration:  7.934e+01 ms
# [06:32:35] - [step:       2800] loss:  3.829e-01, time/iteration:  7.937e+01 ms
# [06:32:43] - [step:       2900] loss:  8.762e-01, time/iteration:  7.918e+01 ms
# [06:32:52] - [step:       3000] record constraint batch time:  8.989e-02s
# [06:32:52] - [step:       3000] record validators time:  1.224e-02s
# [06:32:52] - [step:       3000] saved checkpoint to outputs/fhn2eqtwboth/initial_conditions
# [06:32:52] - [step:       3000] loss:  1.142e-01, time/iteration:  9.019e+01 ms
# [06:32:52] - [step:       3000] reached maximum training steps, finished training!
# [06:32:52] - Solving for Domain window1, iteration 0
# [06:32:52] - attempting to restore from: outputs/fhn2eqtwboth/window1
# [06:32:52] - optimizer checkpoint not found
# [06:32:52] - model network.0.pth not found
# [06:32:52] - [step:          0] record constraint batch time:  9.132e-02s
# [06:32:52] - [step:          0] record validators time:  1.155e-02s
# [06:32:52] - [step:          0] saved checkpoint to outputs/fhn2eqtwboth/window1
# [06:32:52] - [step:          0] loss:  1.340e+01
# [06:32:54] - Attempting cuda graph building, this may take a bit...
# [06:33:03] - [step:        100] loss:  6.267e+00, time/iteration:  1.046e+02 ms
# [06:33:13] - [step:        200] loss:  1.468e+00, time/iteration:  1.005e+02 ms
# [06:33:23] - [step:        300] loss:  1.172e+00, time/iteration:  1.005e+02 ms
# [06:33:33] - [step:        400] loss:  2.569e+00, time/iteration:  1.006e+02 ms
# [06:33:43] - [step:        500] loss:  5.294e-01, time/iteration:  1.005e+02 ms
# [06:33:53] - [step:        600] loss:  4.276e-01, time/iteration:  1.006e+02 ms
# [06:34:03] - [step:        700] loss:  3.921e-01, time/iteration:  1.005e+02 ms
# [06:34:13] - [step:        800] loss:  4.698e+00, time/iteration:  1.003e+02 ms
# [06:34:23] - [step:        900] loss:  3.533e-01, time/iteration:  1.008e+02 ms
# [06:34:34] - [step:       1000] record constraint batch time:  1.018e-01s
# [06:34:34] - [step:       1000] record validators time:  1.217e-02s
# [06:34:34] - [step:       1000] saved checkpoint to outputs/fhn2eqtwboth/window1
# [06:34:34] - [step:       1000] loss:  3.293e-01, time/iteration:  1.116e+02 ms
# [06:34:45] - [step:       1100] loss:  2.567e-01, time/iteration:  1.009e+02 ms
# [06:34:55] - [step:       1200] loss:  3.775e-01, time/iteration:  1.006e+02 ms
# [06:35:05] - [step:       1300] loss:  1.126e+00, time/iteration:  1.004e+02 ms
# [06:35:15] - [step:       1400] loss:  6.762e-01, time/iteration:  1.005e+02 ms
# [06:35:25] - [step:       1500] loss:  1.896e-01, time/iteration:  1.004e+02 ms
# [06:35:35] - [step:       1600] loss:  1.285e+00, time/iteration:  1.006e+02 ms
# [06:35:45] - [step:       1700] loss:  2.570e-01, time/iteration:  1.006e+02 ms
# [06:35:55] - [step:       1800] loss:  9.275e-02, time/iteration:  1.005e+02 ms
# [06:36:05] - [step:       1900] loss:  5.093e-01, time/iteration:  1.006e+02 ms
# [06:36:16] - [step:       2000] record constraint batch time:  1.381e-01s
# [06:36:16] - [step:       2000] record validators time:  1.190e-02s
# [06:36:16] - [step:       2000] saved checkpoint to outputs/fhn2eqtwboth/window1
# [06:36:16] - [step:       2000] loss:  4.280e-01, time/iteration:  1.117e+02 ms
# [06:36:26] - [step:       2100] loss:  5.179e-01, time/iteration:  1.008e+02 ms
# [06:36:36] - [step:       2200] loss:  1.257e+00, time/iteration:  1.004e+02 ms
# [06:36:46] - [step:       2300] loss:  2.271e-01, time/iteration:  1.006e+02 ms
# [06:36:56] - [step:       2400] loss:  1.560e+01, time/iteration:  1.008e+02 ms
# [06:37:06] - [step:       2500] loss:  4.806e-01, time/iteration:  1.006e+02 ms
# [06:37:16] - [step:       2600] loss:  4.093e-01, time/iteration:  1.005e+02 ms
# [06:37:27] - [step:       2700] loss:  1.152e-01, time/iteration:  1.007e+02 ms
# [06:37:37] - [step:       2800] loss:  1.355e-01, time/iteration:  1.004e+02 ms
# [06:37:47] - [step:       2900] loss:  6.499e-01, time/iteration:  1.002e+02 ms
# [06:37:58] - [step:       3000] record constraint batch time:  9.487e-02s
# [06:37:58] - [step:       3000] record validators time:  1.197e-02s
# [06:37:58] - [step:       3000] saved checkpoint to outputs/fhn2eqtwboth/window1
# [06:37:58] - [step:       3000] loss:  9.787e-02, time/iteration:  1.114e+02 ms
# [06:37:58] - [step:       3000] reached maximum training steps, finished training!
# [06:37:58] - Solving for Domain window2, iteration 0
# [06:37:58] - attempting to restore from: outputs/fhn2eqtwboth/window2
# [06:37:58] - optimizer checkpoint not found
# [06:37:58] - model network.0.pth not found
# [06:37:58] - [step:          0] record constraint batch time:  9.440e-02s
# [06:37:58] - [step:          0] record validators time:  1.188e-02s
# [06:37:58] - [step:          0] saved checkpoint to outputs/fhn2eqtwboth/window2
# [06:37:58] - [step:          0] loss:  9.665e-01
# [06:38:01] - Attempting cuda graph building, this may take a bit...
# [06:38:09] - [step:        100] loss:  3.612e+00, time/iteration:  1.049e+02 ms
# [06:38:19] - [step:        200] loss:  3.169e+00, time/iteration:  1.005e+02 ms
# [06:38:29] - [step:        300] loss:  1.945e+00, time/iteration:  1.007e+02 ms
# [06:38:39] - [step:        400] loss:  1.174e+00, time/iteration:  1.007e+02 ms
# [06:38:49] - [step:        500] loss:  1.729e+00, time/iteration:  1.006e+02 ms
# [06:38:59] - [step:        600] loss:  1.446e+00, time/iteration:  1.005e+02 ms
# [06:39:09] - [step:        700] loss:  8.994e-01, time/iteration:  1.004e+02 ms
# [06:39:19] - [step:        800] loss:  1.041e+00, time/iteration:  1.004e+02 ms
# [06:39:29] - [step:        900] loss:  3.648e-01, time/iteration:  1.006e+02 ms
# [06:39:40] - [step:       1000] record constraint batch time:  9.993e-02s
# [06:39:40] - [step:       1000] record validators time:  1.135e-02s
# [06:39:41] - [step:       1000] saved checkpoint to outputs/fhn2eqtwboth/window2
# [06:39:41] - [step:       1000] loss:  1.048e-01, time/iteration:  1.115e+02 ms
# [06:39:51] - [step:       1100] loss:  1.354e+00, time/iteration:  1.009e+02 ms
# [06:40:01] - [step:       1200] loss:  1.189e+00, time/iteration:  1.004e+02 ms
# [06:40:11] - [step:       1300] loss:  1.247e-01, time/iteration:  1.006e+02 ms
# [06:40:21] - [step:       1400] loss:  7.613e-02, time/iteration:  1.006e+02 ms
# [06:40:31] - [step:       1500] loss:  4.010e-01, time/iteration:  1.003e+02 ms
# [06:40:41] - [step:       1600] loss:  9.299e-02, time/iteration:  1.005e+02 ms
# [06:40:51] - [step:       1700] loss:  2.657e-01, time/iteration:  1.006e+02 ms
# [06:41:01] - [step:       1800] loss:  3.338e-02, time/iteration:  1.006e+02 ms
# [06:41:11] - [step:       1900] loss:  5.019e-01, time/iteration:  1.005e+02 ms
# [06:41:22] - [step:       2000] record constraint batch time:  1.378e-01s
# [06:41:22] - [step:       2000] record validators time:  1.169e-02s
# [06:41:22] - [step:       2000] saved checkpoint to outputs/fhn2eqtwboth/window2
# [06:41:22] - [step:       2000] loss:  3.171e-01, time/iteration:  1.117e+02 ms
# [06:41:32] - [step:       2100] loss:  3.334e-01, time/iteration:  1.011e+02 ms
# [06:41:42] - [step:       2200] loss:  1.274e-01, time/iteration:  1.006e+02 ms
# [06:41:52] - [step:       2300] loss:  3.797e-02, time/iteration:  1.006e+02 ms
# [06:42:02] - [step:       2400] loss:  9.630e-01, time/iteration:  1.003e+02 ms
# [06:42:12] - [step:       2500] loss:  7.475e-02, time/iteration:  9.879e+01 ms
# [06:42:22] - [step:       2600] loss:  1.925e-01, time/iteration:  9.768e+01 ms
# [06:42:32] - [step:       2700] loss:  3.996e-01, time/iteration:  9.704e+01 ms
# [06:42:41] - [step:       2800] loss:  5.150e-01, time/iteration:  9.652e+01 ms
# [06:42:51] - [step:       2900] loss:  4.767e-02, time/iteration:  9.616e+01 ms
# [06:43:02] - [step:       3000] record constraint batch time:  9.299e-02s
# [06:43:02] - [step:       3000] record validators time:  1.143e-02s
# [06:43:02] - [step:       3000] saved checkpoint to outputs/fhn2eqtwboth/window2
# [06:43:02] - [step:       3000] loss:  1.344e-01, time/iteration:  1.072e+02 ms
# [06:43:02] - [step:       3000] reached maximum training steps, finished training!
# [06:43:02] - Solving for Domain window3, iteration 0
# [06:43:02] - attempting to restore from: outputs/fhn2eqtwboth/window3
# [06:43:02] - optimizer checkpoint not found
# [06:43:02] - model network.0.pth not found
# [06:43:02] - [step:          0] record constraint batch time:  8.989e-02s
# [06:43:02] - [step:          0] record validators time:  1.141e-02s
# [06:43:03] - [step:          0] saved checkpoint to outputs/fhn2eqtwboth/window3
# [06:43:03] - [step:          0] loss:  7.432e-01
# [06:43:05] - Attempting cuda graph building, this may take a bit...
# [06:43:13] - [step:        100] loss:  5.621e-02, time/iteration:  1.012e+02 ms
# [06:43:22] - [step:        200] loss:  6.562e-02, time/iteration:  9.616e+01 ms
# [06:43:32] - [step:        300] loss:  1.496e-02, time/iteration:  9.619e+01 ms
# [06:43:42] - [step:        400] loss:  1.069e-02, time/iteration:  9.601e+01 ms
# [06:43:51] - [step:        500] loss:  5.025e-03, time/iteration:  9.610e+01 ms
# [06:44:01] - [step:        600] loss:  1.008e-02, time/iteration:  9.600e+01 ms
# [06:44:10] - [step:        700] loss:  3.403e-02, time/iteration:  9.600e+01 ms
# [06:44:20] - [step:        800] loss:  1.950e-03, time/iteration:  9.579e+01 ms
# [06:44:30] - [step:        900] loss:  2.270e-03, time/iteration:  9.611e+01 ms
# [06:44:40] - [step:       1000] record constraint batch time:  9.869e-02s
# [06:44:40] - [step:       1000] record validators time:  1.136e-02s
# [06:44:40] - [step:       1000] saved checkpoint to outputs/fhn2eqtwboth/window3
# [06:44:40] - [step:       1000] loss:  1.009e-02, time/iteration:  1.074e+02 ms
# [06:44:50] - [step:       1100] loss:  1.685e-02, time/iteration:  9.657e+01 ms
# [06:45:00] - [step:       1200] loss:  7.230e-03, time/iteration:  9.631e+01 ms
# [06:45:09] - [step:       1300] loss:  2.402e-02, time/iteration:  9.627e+01 ms
# [06:45:19] - [step:       1400] loss:  1.410e-01, time/iteration:  9.659e+01 ms
# [06:45:28] - [step:       1500] loss:  1.259e-03, time/iteration:  9.663e+01 ms
# [06:45:38] - [step:       1600] loss:  6.123e-03, time/iteration:  9.691e+01 ms
# [06:45:48] - [step:       1700] loss:  1.311e-01, time/iteration:  9.684e+01 ms
# [06:45:58] - [step:       1800] loss:  4.179e-03, time/iteration:  9.715e+01 ms
# [06:46:07] - [step:       1900] loss:  5.232e-02, time/iteration:  9.741e+01 ms
# [06:46:18] - [step:       2000] record constraint batch time:  1.391e-01s
# [06:46:18] - [step:       2000] record validators time:  1.200e-02s
# [06:46:18] - [step:       2000] saved checkpoint to outputs/fhn2eqtwboth/window3
# [06:46:18] - [step:       2000] loss:  3.596e-03, time/iteration:  1.086e+02 ms
# [06:46:28] - [step:       2100] loss:  1.595e-03, time/iteration:  9.817e+01 ms
# [06:46:38] - [step:       2200] loss:  1.509e-01, time/iteration:  9.791e+01 ms
# [06:46:48] - [step:       2300] loss:  1.925e-03, time/iteration:  9.837e+01 ms
# [06:46:58] - [step:       2400] loss:  1.063e-02, time/iteration:  9.901e+01 ms
# [06:47:07] - [step:       2500] loss:  1.959e-02, time/iteration:  9.952e+01 ms
# [06:47:17] - [step:       2600] loss:  1.806e-03, time/iteration:  9.976e+01 ms
# [06:47:27] - [step:       2700] loss:  7.237e-02, time/iteration:  1.002e+02 ms
# [06:47:38] - [step:       2800] loss:  7.503e-04, time/iteration:  1.006e+02 ms
# [06:47:48] - [step:       2900] loss:  6.698e-04, time/iteration:  1.006e+02 ms
# [06:47:59] - [step:       3000] record constraint batch time:  9.479e-02s
# [06:47:59] - [step:       3000] record validators time:  1.161e-02s
# [06:47:59] - [step:       3000] saved checkpoint to outputs/fhn2eqtwboth/window3
# [06:47:59] - [step:       3000] loss:  1.915e-02, time/iteration:  1.121e+02 ms
# [06:47:59] - [step:       3000] reached maximum training steps, finished training!
# [06:47:59] - Solving for Domain window4, iteration 0
# [06:47:59] - attempting to restore from: outputs/fhn2eqtwboth/window4
# [06:47:59] - optimizer checkpoint not found
# [06:47:59] - model network.0.pth not found
# [06:47:59] - [step:          0] record constraint batch time:  9.093e-02s
# [06:47:59] - [step:          0] record validators time:  1.137e-02s
# [06:48:00] - [step:          0] saved checkpoint to outputs/fhn2eqtwboth/window4
# [06:48:00] - [step:          0] loss:  3.958e-02
# [06:48:02] - Attempting cuda graph building, this may take a bit...
# [06:48:10] - [step:        100] loss:  1.306e-02, time/iteration:  1.062e+02 ms
# [06:48:20] - [step:        200] loss:  3.684e-03, time/iteration:  1.008e+02 ms
# [06:48:30] - [step:        300] loss:  2.517e-03, time/iteration:  1.005e+02 ms
# [06:48:40] - [step:        400] loss:  2.261e-03, time/iteration:  1.004e+02 ms
# [06:48:50] - [step:        500] loss:  3.027e-02, time/iteration:  1.003e+02 ms
# [06:49:00] - [step:        600] loss:  1.108e-03, time/iteration:  1.001e+02 ms
# [06:49:10] - [step:        700] loss:  1.056e-02, time/iteration:  1.001e+02 ms
# [06:49:20] - [step:        800] loss:  8.469e-04, time/iteration:  9.980e+01 ms
# [06:49:30] - [step:        900] loss:  1.269e-02, time/iteration:  1.002e+02 ms
# [06:49:41] - [step:       1000] record constraint batch time:  1.008e-01s
# [06:49:41] - [step:       1000] record validators time:  1.205e-02s
# [06:49:42] - [step:       1000] saved checkpoint to outputs/fhn2eqtwboth/window4
# [06:49:42] - [step:       1000] loss:  1.485e-02, time/iteration:  1.117e+02 ms
# [06:49:52] - [step:       1100] loss:  5.350e-04, time/iteration:  1.009e+02 ms
# [06:50:02] - [step:       1200] loss:  3.889e-04, time/iteration:  1.009e+02 ms
# [06:50:12] - [step:       1300] loss:  6.631e-04, time/iteration:  1.007e+02 ms
# [06:50:22] - [step:       1400] loss:  3.445e-04, time/iteration:  1.007e+02 ms
# [06:50:32] - [step:       1500] loss:  1.454e-02, time/iteration:  1.002e+02 ms
# [06:50:42] - [step:       1600] loss:  2.539e-03, time/iteration:  1.003e+02 ms
# [06:50:52] - [step:       1700] loss:  2.794e-04, time/iteration:  1.003e+02 ms
# [06:51:02] - [step:       1800] loss:  3.573e-04, time/iteration:  9.989e+01 ms
# [06:51:12] - [step:       1900] loss:  5.834e-04, time/iteration:  9.977e+01 ms
# [06:51:23] - [step:       2000] record constraint batch time:  1.409e-01s
# [06:51:23] - [step:       2000] record validators time:  1.177e-02s
# [06:51:23] - [step:       2000] saved checkpoint to outputs/fhn2eqtwboth/window4
# [06:51:23] - [step:       2000] loss:  6.843e-04, time/iteration:  1.114e+02 ms
# [06:51:33] - [step:       2100] loss:  3.390e-04, time/iteration:  1.001e+02 ms
# [06:51:43] - [step:       2200] loss:  2.360e-03, time/iteration:  9.970e+01 ms
# [06:51:53] - [step:       2300] loss:  2.710e-02, time/iteration:  1.001e+02 ms
# [06:52:03] - [step:       2400] loss:  4.690e-04, time/iteration:  1.005e+02 ms
# [06:52:13] - [step:       2500] loss:  4.378e-04, time/iteration:  1.010e+02 ms
# [06:52:23] - [step:       2600] loss:  4.660e-03, time/iteration:  1.008e+02 ms
# [06:52:33] - [step:       2700] loss:  9.653e-04, time/iteration:  1.007e+02 ms
# [06:52:43] - [step:       2800] loss:  1.520e-02, time/iteration:  1.004e+02 ms
# [06:52:53] - [step:       2900] loss:  2.570e-02, time/iteration:  1.001e+02 ms
# [06:53:04] - [step:       3000] record constraint batch time:  9.292e-02s
# [06:53:04] - [step:       3000] record validators time:  1.157e-02s
# [06:53:05] - [step:       3000] saved checkpoint to outputs/fhn2eqtwboth/window4
# [06:53:05] - [step:       3000] loss:  5.642e-02, time/iteration:  1.113e+02 ms
# [06:53:05] - [step:       3000] reached maximum training steps, finished training!
# [06:53:05] - Solving for Domain window5, iteration 0
# [06:53:05] - attempting to restore from: outputs/fhn2eqtwboth/window5
# [06:53:05] - optimizer checkpoint not found
# [06:53:05] - model network.0.pth not found
# [06:53:05] - [step:          0] record constraint batch time:  9.300e-02s
# [06:53:05] - [step:          0] record validators time:  1.149e-02s
# [06:53:05] - [step:          0] saved checkpoint to outputs/fhn2eqtwboth/window5
# [06:53:05] - [step:          0] loss:  4.857e-02
# [06:53:07] - Attempting cuda graph building, this may take a bit...
# [06:53:16] - [step:        100] loss:  5.779e-03, time/iteration:  1.059e+02 ms
# [06:53:26] - [step:        200] loss:  1.043e-03, time/iteration:  1.001e+02 ms
# [06:53:36] - [step:        300] loss:  4.361e-04, time/iteration:  1.005e+02 ms
# [06:53:46] - [step:        400] loss:  3.226e-02, time/iteration:  1.004e+02 ms
# [06:53:56] - [step:        500] loss:  1.362e-02, time/iteration:  1.007e+02 ms
# [06:54:06] - [step:        600] loss:  4.905e-04, time/iteration:  1.010e+02 ms
# [06:54:16] - [step:        700] loss:  1.378e-03, time/iteration:  1.006e+02 ms
# [06:54:26] - [step:        800] loss:  5.517e-04, time/iteration:  1.004e+02 ms
# [06:54:36] - [step:        900] loss:  9.916e-04, time/iteration:  1.006e+02 ms
# [06:54:47] - [step:       1000] record constraint batch time:  9.999e-02s
# [06:54:47] - [step:       1000] record validators time:  1.154e-02s
# [06:54:47] - [step:       1000] saved checkpoint to outputs/fhn2eqtwboth/window5
# [06:54:47] - [step:       1000] loss:  1.474e-02, time/iteration:  1.115e+02 ms
# [06:54:57] - [step:       1100] loss:  8.006e-04, time/iteration:  9.945e+01 ms
# [06:55:07] - [step:       1200] loss:  6.613e-03, time/iteration:  9.783e+01 ms
# [06:55:17] - [step:       1300] loss:  2.107e-04, time/iteration:  9.721e+01 ms
# [06:55:27] - [step:       1400] loss:  1.138e-03, time/iteration:  9.669e+01 ms
# [06:55:36] - [step:       1500] loss:  1.870e-02, time/iteration:  9.605e+01 ms
# [06:55:46] - [step:       1600] loss:  5.706e-03, time/iteration:  9.609e+01 ms
# [06:55:55] - [step:       1700] loss:  2.670e-03, time/iteration:  9.612e+01 ms
# [06:56:05] - [step:       1800] loss:  2.403e-03, time/iteration:  9.576e+01 ms
# [06:56:15] - [step:       1900] loss:  5.747e-03, time/iteration:  9.594e+01 ms
# [06:56:25] - [step:       2000] record constraint batch time:  1.369e-01s
# [06:56:25] - [step:       2000] record validators time:  1.165e-02s
# [06:56:25] - [step:       2000] saved checkpoint to outputs/fhn2eqtwboth/window5
# [06:56:25] - [step:       2000] loss:  9.198e-03, time/iteration:  1.073e+02 ms
# [06:56:35] - [step:       2100] loss:  6.764e-03, time/iteration:  9.626e+01 ms
# [06:56:44] - [step:       2200] loss:  1.929e-02, time/iteration:  9.551e+01 ms
# [06:56:54] - [step:       2300] loss:  5.136e-02, time/iteration:  9.565e+01 ms
# [06:57:04] - [step:       2400] loss:  4.581e-03, time/iteration:  9.597e+01 ms
# [06:57:13] - [step:       2500] loss:  2.478e-02, time/iteration:  9.593e+01 ms
# [06:57:23] - [step:       2600] loss:  1.275e-04, time/iteration:  9.598e+01 ms
# [06:57:32] - [step:       2700] loss:  1.400e-02, time/iteration:  9.608e+01 ms
# [06:57:42] - [step:       2800] loss:  8.442e-03, time/iteration:  9.597e+01 ms
# [06:57:52] - [step:       2900] loss:  2.855e-03, time/iteration:  9.599e+01 ms
# [06:58:02] - [step:       3000] record constraint batch time:  9.376e-02s
# [06:58:02] - [step:       3000] record validators time:  1.188e-02s
# [06:58:02] - [step:       3000] saved checkpoint to outputs/fhn2eqtwboth/window5
# [06:58:02] - [step:       3000] loss:  2.232e-03, time/iteration:  1.072e+02 ms
# [06:58:02] - [step:       3000] reached maximum training steps, finished training!
# [06:58:02] - Solving for Domain window6, iteration 0
# [06:58:02] - attempting to restore from: outputs/fhn2eqtwboth/window6
# [06:58:02] - optimizer checkpoint not found
# [06:58:02] - model network.0.pth not found
# [06:58:03] - [step:          0] record constraint batch time:  9.202e-02s
# [06:58:03] - [step:          0] record validators time:  1.165e-02s
# [06:58:03] - [step:          0] saved checkpoint to outputs/fhn2eqtwboth/window6
# [06:58:03] - [step:          0] loss:  2.609e-02
# [06:58:05] - Attempting cuda graph building, this may take a bit...
# [06:58:13] - [step:        100] loss:  3.415e-03, time/iteration:  1.031e+02 ms
# [06:58:23] - [step:        200] loss:  1.206e-03, time/iteration:  9.711e+01 ms
# [06:58:33] - [step:        300] loss:  8.002e-04, time/iteration:  9.713e+01 ms
# [06:58:43] - [step:        400] loss:  6.866e-04, time/iteration:  9.719e+01 ms
# [06:58:52] - [step:        500] loss:  6.404e-04, time/iteration:  9.736e+01 ms
# [06:59:02] - [step:        600] loss:  4.793e-03, time/iteration:  9.749e+01 ms
# [06:59:12] - [step:        700] loss:  4.187e-04, time/iteration:  9.756e+01 ms
# [06:59:22] - [step:        800] loss:  4.529e-04, time/iteration:  9.769e+01 ms
# [06:59:31] - [step:        900] loss:  5.674e-04, time/iteration:  9.842e+01 ms
# [06:59:42] - [step:       1000] record constraint batch time:  1.005e-01s
# [06:59:42] - [step:       1000] record validators time:  1.171e-02s
# [06:59:42] - [step:       1000] saved checkpoint to outputs/fhn2eqtwboth/window6
# [06:59:42] - [step:       1000] loss:  3.109e-04, time/iteration:  1.097e+02 ms
# [06:59:52] - [step:       1100] loss:  1.306e-02, time/iteration:  9.978e+01 ms
# [07:00:02] - [step:       1200] loss:  1.164e-04, time/iteration:  9.959e+01 ms
# [07:00:12] - [step:       1300] loss:  1.304e-04, time/iteration:  1.000e+02 ms
# [07:00:22] - [step:       1400] loss:  9.578e-04, time/iteration:  1.003e+02 ms
# [07:00:32] - [step:       1500] loss:  8.090e-04, time/iteration:  1.007e+02 ms
# [07:00:42] - [step:       1600] loss:  9.728e-05, time/iteration:  1.008e+02 ms
# [07:00:53] - [step:       1700] loss:  7.922e-05, time/iteration:  1.007e+02 ms
# [07:01:03] - [step:       1800] loss:  3.930e-04, time/iteration:  1.004e+02 ms
# [07:01:13] - [step:       1900] loss:  5.307e-05, time/iteration:  1.002e+02 ms
# [07:01:24] - [step:       2000] record constraint batch time:  1.378e-01s
# [07:01:24] - [step:       2000] record validators time:  1.209e-02s
# [07:01:24] - [step:       2000] saved checkpoint to outputs/fhn2eqtwboth/window6
# [07:01:24] - [step:       2000] loss:  1.548e-04, time/iteration:  1.112e+02 ms
# [07:01:34] - [step:       2100] loss:  4.965e-03, time/iteration:  1.002e+02 ms
# [07:01:44] - [step:       2200] loss:  1.603e-03, time/iteration:  9.991e+01 ms
# [07:01:54] - [step:       2300] loss:  2.005e-04, time/iteration:  9.999e+01 ms
# [07:02:04] - [step:       2400] loss:  1.306e-04, time/iteration:  1.001e+02 ms
# [07:02:14] - [step:       2500] loss:  3.248e-04, time/iteration:  1.002e+02 ms
# [07:02:24] - [step:       2600] loss:  4.096e-03, time/iteration:  1.003e+02 ms
# [07:02:34] - [step:       2700] loss:  3.492e-03, time/iteration:  1.004e+02 ms
# [07:02:44] - [step:       2800] loss:  2.650e-03, time/iteration:  1.002e+02 ms
# [07:02:54] - [step:       2900] loss:  1.824e-04, time/iteration:  1.002e+02 ms
# [07:03:05] - [step:       3000] record constraint batch time:  9.360e-02s
# [07:03:05] - [step:       3000] record validators time:  1.150e-02s
# [07:03:05] - [step:       3000] saved checkpoint to outputs/fhn2eqtwboth/window6
# [07:03:05] - [step:       3000] loss:  1.126e-02, time/iteration:  1.114e+02 ms
# [07:03:05] - [step:       3000] reached maximum training steps, finished training!
# [07:03:05] - Solving for Domain window7, iteration 0
# [07:03:05] - attempting to restore from: outputs/fhn2eqtwboth/window7
# [07:03:05] - optimizer checkpoint not found
# [07:03:05] - model network.0.pth not found
# [07:03:06] - [step:          0] record constraint batch time:  9.300e-02s
# [07:03:06] - [step:          0] record validators time:  1.212e-02s
# [07:03:06] - [step:          0] saved checkpoint to outputs/fhn2eqtwboth/window7
# [07:03:06] - [step:          0] loss:  3.378e-02
# [07:03:08] - Attempting cuda graph building, this may take a bit...
# [07:03:16] - [step:        100] loss:  7.120e-03, time/iteration:  1.070e+02 ms
# [07:03:27] - [step:        200] loss:  4.168e-03, time/iteration:  1.006e+02 ms
# [07:03:37] - [step:        300] loss:  3.450e-03, time/iteration:  1.004e+02 ms
# [07:03:47] - [step:        400] loss:  2.381e-03, time/iteration:  1.005e+02 ms
# [07:03:57] - [step:        500] loss:  1.878e-03, time/iteration:  1.004e+02 ms
# [07:04:07] - [step:        600] loss:  1.544e-03, time/iteration:  1.005e+02 ms
# [07:04:17] - [step:        700] loss:  2.006e-03, time/iteration:  1.004e+02 ms
# [07:04:27] - [step:        800] loss:  1.165e-03, time/iteration:  1.005e+02 ms
# [07:04:37] - [step:        900] loss:  9.399e-04, time/iteration:  1.005e+02 ms
# [07:04:48] - [step:       1000] record constraint batch time:  1.005e-01s
# [07:04:48] - [step:       1000] record validators time:  1.202e-02s
# [07:04:48] - [step:       1000] saved checkpoint to outputs/fhn2eqtwboth/window7
# [07:04:48] - [step:       1000] loss:  2.610e-03, time/iteration:  1.127e+02 ms
# [07:04:58] - [step:       1100] loss:  8.371e-04, time/iteration:  1.007e+02 ms
# [07:05:08] - [step:       1200] loss:  7.192e-04, time/iteration:  1.003e+02 ms
# [07:05:18] - [step:       1300] loss:  1.032e-03, time/iteration:  1.004e+02 ms
# [07:05:28] - [step:       1400] loss:  4.450e-04, time/iteration:  1.005e+02 ms
# [07:05:38] - [step:       1500] loss:  6.541e-04, time/iteration:  1.001e+02 ms
# [07:05:48] - [step:       1600] loss:  3.930e-03, time/iteration:  1.005e+02 ms
# [07:05:58] - [step:       1700] loss:  1.154e-02, time/iteration:  1.003e+02 ms
# [07:06:08] - [step:       1800] loss:  9.703e-03, time/iteration:  1.005e+02 ms
# [07:06:19] - [step:       1900] loss:  2.215e-03, time/iteration:  1.005e+02 ms
# [07:06:30] - [step:       2000] record constraint batch time:  1.382e-01s
# [07:06:30] - [step:       2000] record validators time:  1.198e-02s
# [07:06:30] - [step:       2000] saved checkpoint to outputs/fhn2eqtwboth/window7
# [07:06:30] - [step:       2000] loss:  1.183e-03, time/iteration:  1.115e+02 ms
# [07:06:40] - [step:       2100] loss:  2.212e-02, time/iteration:  1.006e+02 ms
# [07:06:50] - [step:       2200] loss:  2.436e-04, time/iteration:  1.002e+02 ms
# [07:07:00] - [step:       2300] loss:  6.387e-04, time/iteration:  1.004e+02 ms
# [07:07:10] - [step:       2400] loss:  2.094e-03, time/iteration:  1.003e+02 ms
# [07:07:20] - [step:       2500] loss:  5.447e-04, time/iteration:  1.006e+02 ms
# [07:07:30] - [step:       2600] loss:  2.636e-03, time/iteration:  1.006e+02 ms
# [07:07:40] - [step:       2700] loss:  2.377e-03, time/iteration:  1.005e+02 ms
# [07:07:50] - [step:       2800] loss:  2.404e-04, time/iteration:  1.005e+02 ms
# [07:08:00] - [step:       2900] loss:  2.182e-04, time/iteration:  1.005e+02 ms
# [07:08:11] - [step:       3000] record constraint batch time:  9.280e-02s
# [07:08:11] - [step:       3000] record validators time:  1.175e-02s
# [07:08:11] - [step:       3000] saved checkpoint to outputs/fhn2eqtwboth/window7
# [07:08:11] - [step:       3000] loss:  6.674e-04, time/iteration:  1.117e+02 ms
# [07:08:11] - [step:       3000] reached maximum training steps, finished training!
# [07:08:11] - Solving for Domain window8, iteration 0
# [07:08:11] - attempting to restore from: outputs/fhn2eqtwboth/window8
# [07:08:11] - optimizer checkpoint not found
# [07:08:11] - model network.0.pth not found
# [07:08:12] - [step:          0] record constraint batch time:  9.615e-02s
# [07:08:12] - [step:          0] record validators time:  1.249e-02s
# [07:08:12] - [step:          0] saved checkpoint to outputs/fhn2eqtwboth/window8
# [07:08:12] - [step:          0] loss:  8.285e-04
# [07:08:14] - Attempting cuda graph building, this may take a bit...
# [07:08:23] - [step:        100] loss:  1.226e-03, time/iteration:  1.095e+02 ms
# [07:08:33] - [step:        200] loss:  4.040e-04, time/iteration:  1.011e+02 ms
# [07:08:43] - [step:        300] loss:  9.693e-03, time/iteration:  1.009e+02 ms
# [07:08:53] - [step:        400] loss:  2.419e-04, time/iteration:  1.006e+02 ms
# [07:09:03] - [step:        500] loss:  1.730e-04, time/iteration:  1.008e+02 ms
# [07:09:13] - [step:        600] loss:  2.177e-04, time/iteration:  1.008e+02 ms
# [07:09:23] - [step:        700] loss:  1.276e-04, time/iteration:  1.007e+02 ms
# [07:09:34] - [step:        800] loss:  1.524e-04, time/iteration:  1.006e+02 ms
# [07:09:44] - [step:        900] loss:  1.568e-04, time/iteration:  1.007e+02 ms
# [07:09:55] - [step:       1000] record constraint batch time:  1.018e-01s
# [07:09:55] - [step:       1000] record validators time:  1.159e-02s
# [07:09:55] - [step:       1000] saved checkpoint to outputs/fhn2eqtwboth/window8
# [07:09:55] - [step:       1000] loss:  1.035e-04, time/iteration:  1.122e+02 ms
# [07:10:05] - [step:       1100] loss:  5.280e-04, time/iteration:  1.012e+02 ms
# [07:10:15] - [step:       1200] loss:  1.813e-03, time/iteration:  1.008e+02 ms
# [07:10:25] - [step:       1300] loss:  1.493e-04, time/iteration:  1.007e+02 ms
# [07:10:35] - [step:       1400] loss:  4.052e-04, time/iteration:  1.016e+02 ms
# [07:10:45] - [step:       1500] loss:  4.716e-04, time/iteration:  1.011e+02 ms
# [07:10:55] - [step:       1600] loss:  2.139e-03, time/iteration:  1.009e+02 ms
# [07:11:06] - [step:       1700] loss:  8.595e-04, time/iteration:  1.010e+02 ms
# [07:11:16] - [step:       1800] loss:  1.335e-04, time/iteration:  1.007e+02 ms
# [07:11:26] - [step:       1900] loss:  1.345e-04, time/iteration:  1.008e+02 ms
# [07:11:37] - [step:       2000] record constraint batch time:  1.392e-01s
# [07:11:37] - [step:       2000] record validators time:  1.256e-02s
# [07:11:37] - [step:       2000] saved checkpoint to outputs/fhn2eqtwboth/window8
# [07:11:37] - [step:       2000] loss:  1.004e-03, time/iteration:  1.129e+02 ms
# [07:11:47] - [step:       2100] loss:  4.324e-04, time/iteration:  1.011e+02 ms
# [07:11:57] - [step:       2200] loss:  2.480e-03, time/iteration:  1.006e+02 ms
# [07:12:07] - [step:       2300] loss:  7.092e-05, time/iteration:  1.007e+02 ms
# [07:12:17] - [step:       2400] loss:  3.859e-03, time/iteration:  1.008e+02 ms
# [07:12:27] - [step:       2500] loss:  7.233e-04, time/iteration:  1.008e+02 ms
# [07:12:37] - [step:       2600] loss:  1.759e-04, time/iteration:  1.010e+02 ms
# [07:12:48] - [step:       2700] loss:  2.094e-03, time/iteration:  1.010e+02 ms
# [07:12:58] - [step:       2800] loss:  8.064e-04, time/iteration:  1.007e+02 ms
# [07:13:08] - [step:       2900] loss:  1.481e-04, time/iteration:  1.006e+02 ms
# [07:13:19] - [step:       3000] record constraint batch time:  9.442e-02s
# [07:13:19] - [step:       3000] record validators time:  1.203e-02s
# [07:13:19] - [step:       3000] saved checkpoint to outputs/fhn2eqtwboth/window8
# [07:13:19] - [step:       3000] loss:  2.515e-03, time/iteration:  1.129e+02 ms
# [07:13:19] - [step:       3000] reached maximum training steps, finished training!
# [07:13:19] - Solving for Domain window9, iteration 0
# [07:13:19] - attempting to restore from: outputs/fhn2eqtwboth/window9
# [07:13:19] - optimizer checkpoint not found
# [07:13:19] - model network.0.pth not found
# [07:13:20] - [step:          0] record constraint batch time:  9.356e-02s
# [07:13:20] - [step:          0] record validators time:  1.226e-02s
# [07:13:20] - [step:          0] saved checkpoint to outputs/fhn2eqtwboth/window9
# [07:13:20] - [step:          0] loss:  1.363e-03
# [07:13:22] - Attempting cuda graph building, this may take a bit...
# [07:13:31] - [step:        100] loss:  3.844e-04, time/iteration:  1.092e+02 ms
# [07:13:41] - [step:        200] loss:  2.894e-04, time/iteration:  1.009e+02 ms
# [07:13:51] - [step:        300] loss:  2.607e-04, time/iteration:  1.011e+02 ms
# [07:14:01] - [step:        400] loss:  2.112e-04, time/iteration:  1.011e+02 ms
# [07:14:11] - [step:        500] loss:  8.477e-04, time/iteration:  1.009e+02 ms
# [07:14:21] - [step:        600] loss:  1.310e-04, time/iteration:  1.010e+02 ms
# [07:14:31] - [step:        700] loss:  4.901e-04, time/iteration:  1.011e+02 ms
# [07:14:41] - [step:        800] loss:  1.005e-03, time/iteration:  1.005e+02 ms
# [07:14:51] - [step:        900] loss:  3.026e-04, time/iteration:  1.009e+02 ms
# [07:15:03] - [step:       1000] record constraint batch time:  1.015e-01s
# [07:15:03] - [step:       1000] record validators time:  1.212e-02s
# [07:15:03] - [step:       1000] saved checkpoint to outputs/fhn2eqtwboth/window9
# [07:15:03] - [step:       1000] loss:  1.260e-04, time/iteration:  1.129e+02 ms
# [07:15:13] - [step:       1100] loss:  1.367e-04, time/iteration:  1.013e+02 ms
# [07:15:23] - [step:       1200] loss:  9.728e-05, time/iteration:  1.008e+02 ms
# [07:15:33] - [step:       1300] loss:  1.001e-04, time/iteration:  1.010e+02 ms
# [07:15:43] - [step:       1400] loss:  1.620e-04, time/iteration:  1.008e+02 ms
# [07:15:53] - [step:       1500] loss:  8.853e-04, time/iteration:  1.004e+02 ms
# [07:16:03] - [step:       1600] loss:  2.203e-04, time/iteration:  1.008e+02 ms
# [07:16:13] - [step:       1700] loss:  2.444e-03, time/iteration:  1.006e+02 ms
# [07:16:23] - [step:       1800] loss:  2.922e-04, time/iteration:  1.005e+02 ms
# [07:16:33] - [step:       1900] loss:  3.474e-04, time/iteration:  1.003e+02 ms
# [07:16:44] - [step:       2000] record constraint batch time:  1.363e-01s
# [07:16:44] - [step:       2000] record validators time:  1.148e-02s
# [07:16:45] - [step:       2000] saved checkpoint to outputs/fhn2eqtwboth/window9
# [07:16:45] - [step:       2000] loss:  9.920e-04, time/iteration:  1.111e+02 ms
# [07:16:55] - [step:       2100] loss:  1.186e-03, time/iteration:  9.998e+01 ms
# [07:17:04] - [step:       2200] loss:  1.305e-03, time/iteration:  9.943e+01 ms
# [07:17:14] - [step:       2300] loss:  7.393e-05, time/iteration:  9.984e+01 ms
# [07:17:24] - [step:       2400] loss:  3.841e-04, time/iteration:  9.992e+01 ms
# [07:17:34] - [step:       2500] loss:  2.051e-04, time/iteration:  1.003e+02 ms
# [07:17:45] - [step:       2600] loss:  1.415e-04, time/iteration:  1.008e+02 ms
# [07:17:55] - [step:       2700] loss:  2.671e-04, time/iteration:  1.009e+02 ms
# [07:18:05] - [step:       2800] loss:  8.842e-05, time/iteration:  1.012e+02 ms
# [07:18:15] - [step:       2900] loss:  9.787e-05, time/iteration:  1.006e+02 ms
# [07:18:26] - [step:       3000] record constraint batch time:  9.417e-02s
# [07:18:26] - [step:       3000] record validators time:  1.219e-02s
# [07:18:26] - [step:       3000] saved checkpoint to outputs/fhn2eqtwboth/window9
# [07:18:26] - [step:       3000] loss:  1.437e-03, time/iteration:  1.122e+02 ms
# [07:18:26] - [step:       3000] reached maximum training steps, finished training!
